# %% [markdown]
# # 0. Install Dependencies
# ### For use in the "tf-tut" environment (`conda activate tf-tut`)

# %%
# !pip install -r requirements.txt
# Out:
# Collecting absl-py==1.3.0 (from -r requirements.txt (line 1))
#   Using cached absl_py-1.3.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse==1.6.3 (from -r requirements.txt (line 2))
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting cachetools==5.2.0 (from -r requirements.txt (line 3))
#   Using cached cachetools-5.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting certifi==2022.12.7 (from -r requirements.txt (line 4))
#   Using cached certifi-2022.12.7-py3-none-any.whl.metadata (2.9 kB)
# Collecting charset-normalizer==2.1.1 (from -r requirements.txt (line 5))
#   Using cached charset_normalizer-2.1.1-py3-none-any.whl.metadata (11 kB)
# Collecting cloudpickle==1.6.0 (from -r requirements.txt (line 6))
#   Using cached cloudpickle-1.6.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: colorama==0.4.6 in c:\users\inst\anaconda3\envs\tf-tut\lib\site-packages (from -r requirements.txt (line 7)) (0.4.6)
# Collecting flatbuffers==22.12.6 (from -r requirements.txt (line 8))
#   Using cached flatbuffers-22.12.6-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting future==0.18.2 (from -r requirements.txt (line 9))
#   Using cached future-0.18.2.tar.gz (829 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting gast==0.4.0 (from -r requirements.txt (line 10))
#   Using cached gast-0.4.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting google-auth==2.15.0 (from -r requirements.txt (line 11))
#   Using cached google_auth-2.15.0-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting google-auth-oauthlib==0.4.6 (from -r requirements.txt (line 12))
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting google-pasta==0.2.0 (from -r requirements.txt (line 13))
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting grpcio==1.51.1 (from -r requirements.txt (line 14))
#   Using cached grpcio-1.51.1-cp39-cp39-win_amd64.whl.metadata (3.9 kB)
# Collecting gym==0.17.3 (from -r requirements.txt (line 15))
#   Using cached gym-0.17.3.tar.gz (1.6 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting gym-notices==0.0.8 (from -r requirements.txt (line 16))
#   Using cached gym_notices-0.0.8-py3-none-any.whl.metadata (1.0 kB)
# Collecting h5py==3.7.0 (from -r requirements.txt (line 17))
#   Using cached h5py-3.7.0-cp39-cp39-win_amd64.whl.metadata (1.8 kB)
# Requirement already satisfied: idna==3.4 in c:\users\inst\anaconda3\envs\tf-tut\lib\site-packages (from -r requirements.txt (line 18)) (3.4)
# Collecting importlib-metadata==5.1.0 (from -r requirements.txt (line 19))
#   Using cached importlib_metadata-5.1.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting keras==2.11.0 (from -r requirements.txt (line 20))
#   Using cached keras-2.11.0-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting keras-rl2==1.0.5 (from -r requirements.txt (line 21))
#   Using cached keras_rl2-1.0.5-py3-none-any.whl.metadata (304 bytes)
# Collecting libclang==14.0.6 (from -r requirements.txt (line 22))
#   Using cached libclang-14.0.6-py2.py3-none-win_amd64.whl.metadata (5.0 kB)
# Collecting Markdown==3.4.1 (from -r requirements.txt (line 23))
#   Using cached Markdown-3.4.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting MarkupSafe==2.1.1 (from -r requirements.txt (line 24))
#   Using cached MarkupSafe-2.1.1-cp39-cp39-win_amd64.whl.metadata (3.2 kB)
# Collecting numpy==1.23.5 (from -r requirements.txt (line 25))
#   Using cached numpy-1.23.5-cp39-cp39-win_amd64.whl.metadata (2.3 kB)
# Collecting oauthlib==3.2.2 (from -r requirements.txt (line 26))
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Collecting opt-einsum==3.3.0 (from -r requirements.txt (line 27))
#   Using cached opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting packaging==22.0 (from -r requirements.txt (line 28))
#   Using cached packaging-22.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting protobuf==3.19.6 (from -r requirements.txt (line 29))
#   Using cached protobuf-3.19.6-cp39-cp39-win_amd64.whl.metadata (807 bytes)
# Collecting pyasn1==0.4.8 (from -r requirements.txt (line 30))
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting pyasn1-modules==0.2.8 (from -r requirements.txt (line 31))
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting pyglet==1.5.0 (from -r requirements.txt (line 32))
#   Using cached pyglet-1.5.0-py2.py3-none-any.whl.metadata (7.6 kB)
# Collecting requests==2.28.1 (from -r requirements.txt (line 33))
#   Using cached requests-2.28.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting requests-oauthlib==1.3.1 (from -r requirements.txt (line 34))
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl.metadata (10 kB)
# Collecting rl-agents==0.1.1 (from -r requirements.txt (line 35))
#   Using cached rl_agents-0.1.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting rsa==4.9 (from -r requirements.txt (line 36))
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting scipy==1.9.3 (from -r requirements.txt (line 37))
#   Using cached scipy-1.9.3-cp39-cp39-win_amd64.whl.metadata (58 kB)
# Collecting setuptools==65.6.3 (from -r requirements.txt (line 38))
#   Using cached setuptools-65.6.3-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: six==1.16.0 in c:\users\inst\anaconda3\envs\tf-tut\lib\site-packages (from -r requirements.txt (line 39)) (1.16.0)
# Collecting tensorboard==2.11.0 (from -r requirements.txt (line 40))
#   Using cached tensorboard-2.11.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting tensorboard-data-server==0.6.1 (from -r requirements.txt (line 41))
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting tensorboard-plugin-wit==1.8.1 (from -r requirements.txt (line 42))
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl.metadata (873 bytes)
# Collecting tensorflow==2.11.0 (from -r requirements.txt (line 43))
#   Using cached tensorflow-2.11.0-cp39-cp39-win_amd64.whl.metadata (2.5 kB)
# Collecting tensorflow-estimator==2.11.0 (from -r requirements.txt (line 44))
#   Using cached tensorflow_estimator-2.11.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting tensorflow-intel==2.11.0 (from -r requirements.txt (line 45))
#   Using cached tensorflow_intel-2.11.0-cp39-cp39-win_amd64.whl.metadata (3.9 kB)
# Collecting tensorflow-io-gcs-filesystem==0.28.0 (from -r requirements.txt (line 46))
#   Using cached tensorflow_io_gcs_filesystem-0.28.0-cp39-cp39-win_amd64.whl.metadata (14 kB)
# Collecting termcolor==2.1.1 (from -r requirements.txt (line 47))
#   Using cached termcolor-2.1.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting tqdm==4.64.1 (from -r requirements.txt (line 48))
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl.metadata (57 kB)
# Collecting typing_extensions==4.4.0 (from -r requirements.txt (line 49))
#   Using cached typing_extensions-4.4.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting urllib3==1.26.13 (from -r requirements.txt (line 50))
#   Using cached urllib3-1.26.13-py2.py3-none-any.whl.metadata (47 kB)
# Collecting Werkzeug==2.2.2 (from -r requirements.txt (line 51))
#   Using cached Werkzeug-2.2.2-py3-none-any.whl.metadata (4.4 kB)
# Collecting wheel==0.38.4 (from -r requirements.txt (line 52))
#   Using cached wheel-0.38.4-py3-none-any.whl.metadata (2.1 kB)
# Collecting wrapt==1.14.1 (from -r requirements.txt (line 53))
#   Using cached wrapt-1.14.1-cp39-cp39-win_amd64.whl.metadata (6.7 kB)
# Collecting zipp==3.11.0 (from -r requirements.txt (line 54))
#   Using cached zipp-3.11.0-py3-none-any.whl.metadata (3.7 kB)
# Using cached absl_py-1.3.0-py3-none-any.whl (124 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Using cached certifi-2022.12.7-py3-none-any.whl (155 kB)
# Using cached charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Using cached cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Using cached flatbuffers-22.12.6-py2.py3-none-any.whl (26 kB)
# Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Using cached google_auth-2.15.0-py2.py3-none-any.whl (177 kB)
# Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Using cached grpcio-1.51.1-cp39-cp39-win_amd64.whl (3.7 MB)
# Using cached gym_notices-0.0.8-py3-none-any.whl (3.0 kB)
# Using cached h5py-3.7.0-cp39-cp39-win_amd64.whl (2.6 MB)
# Using cached importlib_metadata-5.1.0-py3-none-any.whl (21 kB)
# Using cached keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
# Using cached keras_rl2-1.0.5-py3-none-any.whl (52 kB)
# Using cached libclang-14.0.6-py2.py3-none-win_amd64.whl (14.2 MB)
# Using cached Markdown-3.4.1-py3-none-any.whl (93 kB)
# Using cached MarkupSafe-2.1.1-cp39-cp39-win_amd64.whl (17 kB)
# Using cached numpy-1.23.5-cp39-cp39-win_amd64.whl (14.7 MB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Using cached packaging-22.0-py3-none-any.whl (42 kB)
# Using cached protobuf-3.19.6-cp39-cp39-win_amd64.whl (895 kB)
# Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Using cached pyglet-1.5.0-py2.py3-none-any.whl (1.0 MB)
# Using cached requests-2.28.1-py3-none-any.whl (62 kB)
# Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Using cached rl_agents-0.1.1-py3-none-any.whl (17 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached scipy-1.9.3-cp39-cp39-win_amd64.whl (40.2 MB)
# Using cached setuptools-65.6.3-py3-none-any.whl (1.2 MB)
# Using cached tensorboard-2.11.0-py3-none-any.whl (6.0 MB)
# Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Using cached tensorflow-2.11.0-cp39-cp39-win_amd64.whl (1.9 kB)
# Using cached tensorflow_estimator-2.11.0-py2.py3-none-any.whl (439 kB)
# Using cached tensorflow_intel-2.11.0-cp39-cp39-win_amd64.whl (266.3 MB)
# Using cached tensorflow_io_gcs_filesystem-0.28.0-cp39-cp39-win_amd64.whl (1.5 MB)
# Using cached termcolor-2.1.1-py3-none-any.whl (6.2 kB)
# Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# Using cached typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Using cached urllib3-1.26.13-py2.py3-none-any.whl (140 kB)
# Using cached Werkzeug-2.2.2-py3-none-any.whl (232 kB)
# Using cached wheel-0.38.4-py3-none-any.whl (36 kB)
# Using cached wrapt-1.14.1-cp39-cp39-win_amd64.whl (35 kB)
# Using cached zipp-3.11.0-py3-none-any.whl (6.6 kB)
# Building wheels for collected packages: future, gym
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491085 sha256=65641685dee3fd084876527ef6425c1f510f8cba3daa51aa916420f7f658363e
#   Stored in directory: c:\users\inst\appdata\local\pip\cache\wheels\2f\a0\d3\4030d9f80e6b3be787f19fc911b8e7aa462986a40ab1e4bb94
#   Building wheel for gym (setup.py): started
#   Building wheel for gym (setup.py): finished with status 'done'
#   Created wheel for gym: filename=gym-0.17.3-py3-none-any.whl size=1654628 sha256=ab712297fb62b0cec6a50a55a6ea9a24f327a16b8237a1d16d53c2e5fe08ec20
#   Stored in directory: c:\users\inst\appdata\local\pip\cache\wheels\5d\06\a4\57a926b2e87a5e1f21551577750549206dde639e19a5ac72d5
# Successfully built future gym
# Installing collected packages: tensorboard-plugin-wit, pyasn1, libclang, gym-notices, flatbuffers, zipp, wrapt, wheel, urllib3, typing_extensions, tqdm, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, setuptools, rsa, pyasn1-modules, protobuf, packaging, oauthlib, numpy, MarkupSafe, keras, grpcio, google-pasta, gast, future, cloudpickle, charset-normalizer, certifi, cachetools, absl-py, Werkzeug, scipy, requests, pyglet, opt-einsum, importlib-metadata, h5py, google-auth, astunparse, requests-oauthlib, Markdown, gym, rl-agents, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow, keras-rl2
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.17.0
#     Uninstalling zipp-3.17.0:
#       Successfully uninstalled zipp-3.17.0
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.41.2
#     Uninstalling wheel-0.41.2:
#       Successfully uninstalled wheel-0.41.2
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.1.0
#     Uninstalling urllib3-2.1.0:
#       Successfully uninstalled urllib3-2.1.0
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.9.0
#     Uninstalling typing_extensions-4.9.0:
#       Successfully uninstalled typing_extensions-4.9.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 68.2.2
#     Uninstalling setuptools-68.2.2:
#       Successfully uninstalled setuptools-68.2.2
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.2
#     Uninstalling packaging-23.2:
#       Successfully uninstalled packaging-23.2
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.1.3
#     Uninstalling MarkupSafe-2.1.3:
#       Successfully uninstalled MarkupSafe-2.1.3
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 2.0.4
#     Uninstalling charset-normalizer-2.0.4:
#       Successfully uninstalled charset-normalizer-2.0.4
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2024.2.2
#     Uninstalling certifi-2024.2.2:
#       Successfully uninstalled certifi-2024.2.2
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 7.0.1
#     Uninstalling importlib-metadata-7.0.1:
#       Successfully uninstalled importlib-metadata-7.0.1
# Successfully installed Markdown-3.4.1 MarkupSafe-2.1.1 Werkzeug-2.2.2 absl-py-1.3.0 astunparse-1.6.3 cachetools-5.2.0 certifi-2022.12.7 charset-normalizer-2.1.1 cloudpickle-1.6.0 flatbuffers-22.12.6 future-0.18.2 gast-0.4.0 google-auth-2.15.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.51.1 gym-0.17.3 gym-notices-0.0.8 h5py-3.7.0 importlib-metadata-5.1.0 keras-2.11.0 keras-rl2-1.0.5 libclang-14.0.6 numpy-1.23.5 oauthlib-3.2.2 opt-einsum-3.3.0 packaging-22.0 protobuf-3.19.6 pyasn1-0.4.8 pyasn1-modules-0.2.8 pyglet-1.5.0 requests-2.28.1 requests-oauthlib-1.3.1 rl-agents-0.1.1 rsa-4.9 scipy-1.9.3 setuptools-65.6.3 tensorboard-2.11.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.11.0 tensorflow-estimator-2.11.0 tensorflow-intel-2.11.0 tensorflow-io-gcs-filesystem-0.28.0 termcolor-2.1.1 tqdm-4.64.1 typing_extensions-4.4.0 urllib3-1.26.13 wheel-0.38.4 wrapt-1.14.1 zipp-3.11.0
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\inst\anaconda3\envs\tf-tut\Lib\site-packages\~arkupsafe'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyterlab-server 2.25.1 requires requests>=2.31, but you have requests 2.28.1 which is incompatible.

# %%
# !pip install gym==0.17.2
# !pip install gym[classic_control]
# Out:
# Collecting gym==0.17.2
#   Downloading gym-0.17.2.tar.gz (1.6 MB)
#      ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#      - -------------------------------------- 0.0/1.6 MB 393.8 kB/s eta 0:00:04
#      ------- -------------------------------- 0.3/1.6 MB 2.1 MB/s eta 0:00:01
#      ------------------------- -------------- 1.0/1.6 MB 5.2 MB/s eta 0:00:01
#      ---------------------------------------  1.6/1.6 MB 7.7 MB/s eta 0:00:01
#      ---------------------------------------- 1.6/1.6 MB 6.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting scipy (from gym==0.17.2)
#   Using cached scipy-1.10.1-cp38-cp38-win_amd64.whl.metadata (58 kB)
# Collecting numpy>=1.10.4 (from gym==0.17.2)
#   Using cached numpy-1.24.4-cp38-cp38-win_amd64.whl.metadata (5.6 kB)
# Collecting pyglet<=1.5.0,>=1.4.0 (from gym==0.17.2)
#   Downloading pyglet-1.5.0-py2.py3-none-any.whl.metadata (7.6 kB)
# Collecting cloudpickle<1.4.0,>=1.2.0 (from gym==0.17.2)
#   Downloading cloudpickle-1.3.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting future (from pyglet<=1.5.0,>=1.4.0->gym==0.17.2)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Downloading cloudpickle-1.3.0-py2.py3-none-any.whl (26 kB)
# Using cached numpy-1.24.4-cp38-cp38-win_amd64.whl (14.9 MB)
# Downloading pyglet-1.5.0-py2.py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------  1.0/1.0 MB 32.4 MB/s eta 0:00:01
#    ---------------------------------------  1.0/1.0 MB 32.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 10.8 MB/s eta 0:00:00
# Using cached scipy-1.10.1-cp38-cp38-win_amd64.whl (42.2 MB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
#    ---------------------------------------- 0.0/491.3 kB ? eta -:--:--
#    ---------------------------------------  481.3/491.3 kB ? eta -:--:--
#    --------------------------------------- 491.3/491.3 kB 10.2 MB/s eta 0:00:00
# Building wheels for collected packages: gym
#   Building wheel for gym (setup.py): started
#   Building wheel for gym (setup.py): finished with status 'done'
#   Created wheel for gym: filename=gym-0.17.2-py3-none-any.whl size=1650869 sha256=14099e5ec6421f09e34e4ab2696565183ec8ef8358b311b87f80ecaa884304f3
#   Stored in directory: c:\users\inst\appdata\local\pip\cache\wheels\48\bf\7c\44b1b8e4ad998fc48e31caedbb9e028351861b8d20632642bc
# Successfully built gym
# Installing collected packages: cloudpickle, numpy, future, scipy, pyglet, gym
# Successfully installed cloudpickle-1.3.0 future-1.0.0 gym-0.17.2 numpy-1.24.4 pyglet-1.5.0 scipy-1.10.1

# %%
# !pip install tensorflow==2.3.0
# Out:
# Collecting tensorflow==2.3.0
#   Using cached tensorflow-2.3.0-cp38-cp38-win_amd64.whl.metadata (2.6 kB)
# Collecting absl-py>=0.7.0 (from tensorflow==2.3.0)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse==1.6.3 (from tensorflow==2.3.0)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting gast==0.3.3 (from tensorflow==2.3.0)
#   Using cached gast-0.3.3-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting google-pasta>=0.1.8 (from tensorflow==2.3.0)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py<2.11.0,>=2.10.0 (from tensorflow==2.3.0)
#   Using cached h5py-2.10.0-cp38-cp38-win_amd64.whl.metadata (2.0 kB)
# Collecting keras-preprocessing<1.2,>=1.1.1 (from tensorflow==2.3.0)
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting numpy<1.19.0,>=1.16.0 (from tensorflow==2.3.0)
#   Using cached numpy-1.18.5-cp38-cp38-win_amd64.whl.metadata (2.1 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow==2.3.0)
#   Using cached opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting protobuf>=3.9.2 (from tensorflow==2.3.0)
#   Using cached protobuf-5.26.1-cp38-cp38-win_amd64.whl.metadata (592 bytes)
# Collecting tensorboard<3,>=2.3.0 (from tensorflow==2.3.0)
#   Using cached tensorboard-2.14.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting tensorflow-estimator<2.4.0,>=2.3.0 (from tensorflow==2.3.0)
#   Using cached tensorflow_estimator-2.3.0-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting termcolor>=1.1.0 (from tensorflow==2.3.0)
#   Using cached termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting wrapt>=1.11.1 (from tensorflow==2.3.0)
#   Using cached wrapt-1.16.0-cp38-cp38-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: wheel>=0.26 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from tensorflow==2.3.0) (0.41.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from tensorflow==2.3.0) (1.16.0)
# Collecting scipy==1.4.1 (from tensorflow==2.3.0)
#   Using cached scipy-1.4.1-cp38-cp38-win_amd64.whl.metadata (2.0 kB)
# Collecting grpcio>=1.8.6 (from tensorflow==2.3.0)
#   Using cached grpcio-1.62.1-cp38-cp38-win_amd64.whl.metadata (4.2 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<3,>=2.3.0->tensorflow==2.3.0)
#   Using cached google_auth-2.29.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard<3,>=2.3.0->tensorflow==2.3.0)
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard<3,>=2.3.0->tensorflow==2.3.0)
#   Using cached Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (68.2.2)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<3,>=2.3.0->tensorflow==2.3.0)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<3,>=2.3.0->tensorflow==2.3.0)
#   Using cached werkzeug-3.0.2-py3-none-any.whl.metadata (4.1 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0)
#   Using cached cachetools-5.3.3-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0)
#   Using cached pyasn1_modules-0.4.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0)
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<1.1,>=0.5->tensorboard<3,>=2.3.0->tensorflow==2.3.0)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (7.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from werkzeug>=1.0.1->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.17.0)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0)
#   Using cached pyasn1-0.6.0-py2.py3-none-any.whl.metadata (8.3 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<3,>=2.3.0->tensorflow==2.3.0)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Using cached tensorflow-2.3.0-cp38-cp38-win_amd64.whl (342.5 MB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Using cached scipy-1.4.1-cp38-cp38-win_amd64.whl (31.0 MB)
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Using cached grpcio-1.62.1-cp38-cp38-win_amd64.whl (3.8 MB)
# Using cached h5py-2.10.0-cp38-cp38-win_amd64.whl (2.5 MB)
# Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Using cached numpy-1.18.5-cp38-cp38-win_amd64.whl (12.8 MB)
# Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Using cached protobuf-5.26.1-cp38-cp38-win_amd64.whl (420 kB)
# Using cached tensorboard-2.14.0-py3-none-any.whl (5.5 MB)
# Using cached tensorflow_estimator-2.3.0-py2.py3-none-any.whl (459 kB)
# Using cached termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Using cached wrapt-1.16.0-cp38-cp38-win_amd64.whl (37 kB)
# Using cached google_auth-2.29.0-py2.py3-none-any.whl (189 kB)
# Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Using cached Markdown-3.6-py3-none-any.whl (105 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached werkzeug-3.0.2-py3-none-any.whl (226 kB)
# Using cached cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Using cached pyasn1_modules-0.4.0-py3-none-any.whl (181 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached pyasn1-0.6.0-py2.py3-none-any.whl (85 kB)
# Installing collected packages: tensorflow-estimator, wrapt, werkzeug, termcolor, tensorboard-data-server, pyasn1, protobuf, oauthlib, numpy, grpcio, google-pasta, gast, cachetools, astunparse, absl-py, scipy, rsa, requests-oauthlib, pyasn1-modules, opt-einsum, markdown, keras-preprocessing, h5py, google-auth, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.4
#     Uninstalling numpy-1.24.4:
#       Successfully uninstalled numpy-1.24.4
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.1
#     Uninstalling scipy-1.10.1:
#       Successfully uninstalled scipy-1.10.1
# Successfully installed absl-py-2.1.0 astunparse-1.6.3 cachetools-5.3.3 gast-0.3.3 google-auth-2.29.0 google-auth-oauthlib-1.0.0 google-pasta-0.2.0 grpcio-1.62.1 h5py-2.10.0 keras-preprocessing-1.1.2 markdown-3.6 numpy-1.18.5 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-5.26.1 pyasn1-0.6.0 pyasn1-modules-0.4.0 requests-oauthlib-2.0.0 rsa-4.9 scipy-1.4.1 tensorboard-2.14.0 tensorboard-data-server-0.7.2 tensorflow-2.3.0 tensorflow-estimator-2.3.0 termcolor-2.4.0 werkzeug-3.0.2 wrapt-1.16.0

# %%
import tensorflow
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import tensorflow
#
# File ~\anaconda3\envs\tut-tf\lib\site-packages\tensorflow\__init__.py:41
#      38 import six as _six
#      39 import sys as _sys
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      44 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File ~\anaconda3\envs\tut-tf\lib\site-packages\tensorflow\python\__init__.py:40
#      31 import traceback
#      33 # We aim to keep this file minimal and ideally remove completely.
#      34 # If you are adding a new file with @tf_export decorators,
#      35 # import it in modules_with_exports.py instead.
#      36
#      37 # go/tf-wildcard-import
#      38 # pylint: disable=wildcard-import,g-bad-import-order,g-import-not-at-top
# ---> 40 from tensorflow.python.eager import context
#      42 # pylint: enable=wildcard-import
#      43
#      44 # Bring in subpackages.
#      45 from tensorflow.python import data
#
# File ~\anaconda3\envs\tut-tf\lib\site-packages\tensorflow\python\eager\context.py:32
#      29 import numpy as np
#      30 import six
# ---> 32 from tensorflow.core.framework import function_pb2
#      33 from tensorflow.core.protobuf import config_pb2
#      34 from tensorflow.core.protobuf import rewriter_config_pb2
#
# File ~\anaconda3\envs\tut-tf\lib\site-packages\tensorflow\core\framework\function_pb2.py:16
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import attr_value_pb2 as tensorflow_dot_core_dot_framework_dot_attr__value__pb2
#      17 from tensorflow.core.framework import node_def_pb2 as tensorflow_dot_core_dot_framework_dot_node__def__pb2
#      18 from tensorflow.core.framework import op_def_pb2 as tensorflow_dot_core_dot_framework_dot_op__def__pb2
#
# File ~\anaconda3\envs\tut-tf\lib\site-packages\tensorflow\core\framework\attr_value_pb2.py:16
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import tensor_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__pb2
#      17 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      18 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#
# File ~\anaconda3\envs\tut-tf\lib\site-packages\tensorflow\core\framework\tensor_pb2.py:16
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import resource_handle_pb2 as tensorflow_dot_core_dot_framework_dot_resource__handle__pb2
#      17 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      18 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#
# File ~\anaconda3\envs\tut-tf\lib\site-packages\tensorflow\core\framework\resource_handle_pb2.py:16
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      17 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#      20 DESCRIPTOR = _descriptor.FileDescriptor(
#      21   name='tensorflow/core/framework/resource_handle.proto',
#      22   package='tensorflow',
#    (...)
#      26   ,
#      27   dependencies=[tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2.DESCRIPTOR,tensorflow_dot_core_dot_framework_dot_types__pb2.DESCRIPTOR,])
#
# File ~\anaconda3\envs\tut-tf\lib\site-packages\tensorflow\core\framework\tensor_shape_pb2.py:36
#      13 _sym_db = _symbol_database.Default()
#      18 DESCRIPTOR = _descriptor.FileDescriptor(
#      19   name='tensorflow/core/framework/tensor_shape.proto',
#      20   package='tensorflow',
#    (...)
#      23   serialized_pb=_b('\n,tensorflow/core/framework/tensor_shape.proto\x12\ntensorflow\"z\n\x10TensorShapeProto\x12-\n\x03\x64im\x18\x02 \x03(\x0b\x32 .tensorflow.TensorShapeProto.Dim\x12\x14\n\x0cunknown_rank\x18\x03 \x01(\x08\x1a!\n\x03\x44im\x12\x0c\n\x04size\x18\x01 \x01(\x03\x12\x0c\n\x04name\x18\x02 \x01(\tB\x87\x01\n\x18org.tensorflow.frameworkB\x11TensorShapeProtosP\x01ZSgithub.com/tensorflow/tensorflow/tensorflow/go/core/framework/tensor_shape_go_proto\xf8\x01\x01\x62\x06proto3')
#      24 )
#      29 _TENSORSHAPEPROTO_DIM = _descriptor.Descriptor(
#      30   name='Dim',
#      31   full_name='tensorflow.TensorShapeProto.Dim',
#      32   filename=None,
#      33   file=DESCRIPTOR,
#      34   containing_type=None,
#      35   fields=[
# ---> 36     _descriptor.FieldDescriptor(
#      37       name='size', full_name='tensorflow.TensorShapeProto.Dim.size', index=0,
#      38       number=1, type=3, cpp_type=2, label=1,
#      39       has_default_value=False, default_value=0,
#      40       message_type=None, enum_type=None, containing_type=None,
#      41       is_extension=False, extension_scope=None,
#      42       serialized_options=None, file=DESCRIPTOR),
#      43     _descriptor.FieldDescriptor(
#      44       name='name', full_name='tensorflow.TensorShapeProto.Dim.name', index=1,
#      45       number=2, type=9, cpp_type=9, label=1,
#      46       has_default_value=False, default_value=_b("").decode('utf-8'),
#      47       message_type=None, enum_type=None, containing_type=None,
#      48       is_extension=False, extension_scope=None,
#      49       serialized_options=None, file=DESCRIPTOR),
#      50   ],
#      51   extensions=[
#      52   ],
#      53   nested_types=[],
#      54   enum_types=[
#      55   ],
#      56   serialized_options=None,
#      57   is_extendable=False,
#      58   syntax='proto3',
#      59   extension_ranges=[],
#      60   oneofs=[
#      61   ],
#      62   serialized_start=149,
#      63   serialized_end=182,
#      64 )
#      66 _TENSORSHAPEPROTO = _descriptor.Descriptor(
#      67   name='TensorShapeProto',
#      68   full_name='tensorflow.TensorShapeProto',
#    (...)
#     100   serialized_end=182,
#     101 )
#     103 _TENSORSHAPEPROTO_DIM.containing_type = _TENSORSHAPEPROTO
#
# File ~\anaconda3\envs\tut-tf\lib\site-packages\google\protobuf\descriptor.py:621, in FieldDescriptor.__new__(cls, name, full_name, index, number, type, cpp_type, label, default_value, message_type, enum_type, containing_type, is_extension, extension_scope, options, serialized_options, has_default_value, containing_oneof, json_name, file, create_key)
#     615 def __new__(cls, name, full_name, index, number, type, cpp_type, label,
#     616             default_value, message_type, enum_type, containing_type,
#     617             is_extension, extension_scope, options=None,
#     618             serialized_options=None,
#     619             has_default_value=True, containing_oneof=None, json_name=None,
#     620             file=None, create_key=None):  # pylint: disable=redefined-builtin
# --> 621   _message.Message._CheckCalledFromGeneratedFile()
#     622   if is_extension:
#     623     return _message.default_pool.FindExtensionByName(full_name)
#
# TypeError: Descriptors cannot be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates

# %%
# !pip install keras==2.4.3
# Out:
# Collecting keras==2.4.3
#   Using cached Keras-2.4.3-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from keras==2.4.3) (1.18.5)
# Requirement already satisfied: scipy>=0.14 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from keras==2.4.3) (1.4.1)
# Requirement already satisfied: pyyaml in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from keras==2.4.3) (6.0)
# Requirement already satisfied: h5py in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from keras==2.4.3) (2.10.0)
# Requirement already satisfied: six in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from h5py->keras==2.4.3) (1.16.0)
# Using cached Keras-2.4.3-py2.py3-none-any.whl (36 kB)
# Installing collected packages: keras
# Successfully installed keras-2.4.3

# %%
# !pip install keras-rl2==1.0.4
# Out:
# Collecting keras-rl2==1.0.4
#   Using cached keras_rl2-1.0.4-py3-none-any.whl.metadata (353 bytes)
# Requirement already satisfied: tensorflow>=2.1.0 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from keras-rl2==1.0.4) (2.3.0)
# Requirement already satisfied: absl-py>=0.7.0 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2==1.0.4) (2.1.0)
# Requirement already satisfied: astunparse==1.6.3 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2==1.0.4) (1.6.3)
# Requirement already satisfied: gast==0.3.3 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2==1.0.4) (0.3.3)
# Requirement already satisfied: google-pasta>=0.1.8 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2==1.0.4) (0.2.0)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2==1.0.4) (2.10.0)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2==1.0.4) (1.1.2)
# Requirement already satisfied: numpy<1.19.0,>=1.16.0 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2==1.0.4) (1.18.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2==1.0.4) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2==1.0.4) (5.26.1)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2==1.0.4) (2.14.0)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2==1.0.4) (2.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2==1.0.4) (2.4.0)
# Requirement already satisfied: wrapt>=1.11.1 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2==1.0.4) (1.16.0)
# Requirement already satisfied: wheel>=0.26 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2==1.0.4) (0.41.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2==1.0.4) (1.16.0)
# Requirement already satisfied: scipy==1.4.1 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2==1.0.4) (1.4.1)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2==1.0.4) (1.62.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2==1.0.4) (2.29.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2==1.0.4) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2==1.0.4) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2==1.0.4) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2==1.0.4) (68.2.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2==1.0.4) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2==1.0.4) (3.0.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2==1.0.4) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2==1.0.4) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2==1.0.4) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2==1.0.4) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2==1.0.4) (7.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2==1.0.4) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2==1.0.4) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2==1.0.4) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2==1.0.4) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from werkzeug>=1.0.1->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2==1.0.4) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2==1.0.4) (3.17.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2==1.0.4) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\inst\anaconda3\envs\tut-tf\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2==1.0.4) (3.2.2)
# Using cached keras_rl2-1.0.4-py3-none-any.whl (53 kB)
# Installing collected packages: keras-rl2
# Successfully installed keras-rl2-1.0.4

# %%
# tensorflow 2.3.0 requires h5py<2.11.0,>=2.10.0, but you have h5py 3.10.0 which is incompatible.
# tensorflow 2.3.0 requires numpy<1.19.0,>=1.16.0, but you have numpy 1.24.4 which is incompatible.
# tensorflow 2.3.0 requires scipy==1.4.1, but you have scipy 1.10.1 which is incompatible.

# !pip install --force-reinstall h5py==2.10.0
# !pip install --force-reinstall numpy==1.16.0
# !pip install --force-reinstall scipy==1.4.1

# %%
# !pip list | grep tensorflow
# Out:
# 'grep' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# # 1. Test random environment with OpenAI Gym

# %%
# import gymnasium as gym
import random
import gym
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 # import gymnasium as gym
#       2 import random
# ----> 3 import gym
#
# ModuleNotFoundError: No module named 'gym'

# %%
# rendermode = "human"
rendermode = "rgb_array"
env = gym.make('CartPole-v0')
states = env.observation_space.shape[0]
actions = env.action_space.n

# %%
episodes = 10
for episode in range(1,episodes+1):
    state = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action = random.choice([0,1])
        n_state, reward, done, info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode,score))
# Out:
# Episode:1 Score:14.0
# Episode:2 Score:16.0
# Episode:3 Score:37.0
# Episode:4 Score:13.0
# Episode:5 Score:22.0
# Episode:6 Score:19.0
# Episode:7 Score:14.0
# Episode:8 Score:15.0
# Episode:9 Score:13.0
# Episode:10 Score:12.0

# %% [markdown]
# # 2. Create Deep Learning Model with Keras

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers.legacy import Adam
from rl.agents import DQNAgent
from rl.policy import BoltzmannQPolicy
from rl.memory import SequentialMemory

# %%
def build_model(states, actions):
    model = Sequential()
    model.add(Flatten(input_shape=(1,states)))
    model.add(Dense(24, activation='relu'))
    model.add(Dense(24, activation='relu'))
    model.add(Dense(actions, activation='linear'))
    return model

# %%
model = build_model(states, actions)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 4)                 0
#
#  dense (Dense)               (None, 24)                120
#
#  dense_1 (Dense)             (None, 24)                600
#
#  dense_2 (Dense)             (None, 2)                 50
#
# =================================================================
# Total params: 770
# Trainable params: 770
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Build Agent with Keras-RL

# %%
from tensorflow.keras import __version__
import tensorflow
tensorflow.keras.__version__ = __version__

# %%
def build_agent(model, actions):
    policy = BoltzmannQPolicy()
    memory = SequentialMemory(limit=50000, window_length=1)
    dqn = DQNAgent(model=model, memory=memory, policy=policy, nb_actions=actions, nb_steps_warmup=10, target_model_update=1e-2)
    return dqn

# %%
dqn = build_agent(model, actions)
dqn.compile(Adam(learning_rate=1e-3), metrics=['mae'])
dqn.fit(env, nb_steps=50000, visualize=False, verbose=1)
# Out:
# WARNING:tensorflow:From C:\Users\inst\anaconda3\envs\tf-tut\lib\site-packages\tensorflow\python\autograph\pyct\static_analysis\liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
#     1/10000 [..............................] - ETA: 10:09 - reward: 1.0000
# C:\Users\inst\anaconda3\envs\tf-tut\lib\site-packages\keras\engine\training_v1.py:2357: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# C:\Users\inst\anaconda3\envs\tf-tut\lib\site-packages\rl\memory.py:37: UserWarning: Not enough entries to sample without replacement. Consider increasing your warm-up phase to avoid oversampling!
#   warnings.warn('Not enough entries to sample without replacement. Consider increasing your warm-up phase to avoid oversampling!')
# 10000/10000 [==============================] - 58s 6ms/step - reward: 1.0000
# 122 episodes - episode_reward: 81.500 [9.000, 200.000] - loss: 2.743 - mae: 19.063 - mean_q: 38.712
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: 1.0000
# 56 episodes - episode_reward: 179.125 [119.000, 200.000] - loss: 4.746 - mae: 38.946 - mean_q: 78.808
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 58s 6ms/step - reward: 1.0000
# 56 episodes - episode_reward: 178.393 [139.000, 200.000] - loss: 4.515 - mae: 40.450 - mean_q: 81.563
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: 1.0000
# 56 episodes - episode_reward: 178.857 [142.000, 200.000] - loss: 3.581 - mae: 37.902 - mean_q: 76.249
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: 1.0000
# done, took 294.103 seconds

# %%
scores = dqn.test(env, nb_episodes=100, visualize=False)
print(np.mean(scores.history['episode_reward']))
# Out:
# Testing for 100 episodes ...
# Episode 1: reward: 200.000, steps: 200
# Episode 2: reward: 200.000, steps: 200
# Episode 3: reward: 200.000, steps: 200
# Episode 4: reward: 200.000, steps: 200
# Episode 5: reward: 200.000, steps: 200
# Episode 6: reward: 200.000, steps: 200
# Episode 7: reward: 200.000, steps: 200
# Episode 8: reward: 200.000, steps: 200
# Episode 9: reward: 200.000, steps: 200
# Episode 10: reward: 200.000, steps: 200
# Episode 11: reward: 200.000, steps: 200
# Episode 12: reward: 200.000, steps: 200
# Episode 13: reward: 200.000, steps: 200
# Episode 14: reward: 200.000, steps: 200
# Episode 15: reward: 200.000, steps: 200
# Episode 16: reward: 200.000, steps: 200
# Episode 17: reward: 200.000, steps: 200
# Episode 18: reward: 200.000, steps: 200
# Episode 19: reward: 200.000, steps: 200
# Episode 20: reward: 200.000, steps: 200
# Episode 21: reward: 200.000, steps: 200
# Episode 22: reward: 200.000, steps: 200
# Episode 23: reward: 200.000, steps: 200
# Episode 24: reward: 200.000, steps: 200
# Episode 25: reward: 200.000, steps: 200
# Episode 26: reward: 200.000, steps: 200
# Episode 27: reward: 200.000, steps: 200
# Episode 28: reward: 200.000, steps: 200
# Episode 29: reward: 200.000, steps: 200
# Episode 30: reward: 200.000, steps: 200
# Episode 31: reward: 200.000, steps: 200
# Episode 32: reward: 200.000, steps: 200
# Episode 33: reward: 200.000, steps: 200
# Episode 34: reward: 200.000, steps: 200
# Episode 35: reward: 200.000, steps: 200
# Episode 36: reward: 200.000, steps: 200
# Episode 37: reward: 200.000, steps: 200
# Episode 38: reward: 200.000, steps: 200
# Episode 39: reward: 200.000, steps: 200
# Episode 40: reward: 200.000, steps: 200
# Episode 41: reward: 200.000, steps: 200
# Episode 42: reward: 200.000, steps: 200
# Episode 43: reward: 200.000, steps: 200
# Episode 44: reward: 200.000, steps: 200
# Episode 45: reward: 200.000, steps: 200
# Episode 46: reward: 200.000, steps: 200
# Episode 47: reward: 200.000, steps: 200
# Episode 48: reward: 200.000, steps: 200
# Episode 49: reward: 200.000, steps: 200
# Episode 50: reward: 200.000, steps: 200
# Episode 51: reward: 200.000, steps: 200
# Episode 52: reward: 200.000, steps: 200
# Episode 53: reward: 200.000, steps: 200
# Episode 54: reward: 200.000, steps: 200
# Episode 55: reward: 200.000, steps: 200
# Episode 56: reward: 200.000, steps: 200
# Episode 57: reward: 200.000, steps: 200
# Episode 58: reward: 200.000, steps: 200
# Episode 59: reward: 200.000, steps: 200
# Episode 60: reward: 200.000, steps: 200
# Episode 61: reward: 200.000, steps: 200
# Episode 62: reward: 200.000, steps: 200
# Episode 63: reward: 200.000, steps: 200
# Episode 64: reward: 200.000, steps: 200
# Episode 65: reward: 200.000, steps: 200
# Episode 66: reward: 200.000, steps: 200
# Episode 67: reward: 200.000, steps: 200
# Episode 68: reward: 200.000, steps: 200
# Episode 69: reward: 200.000, steps: 200
# Episode 70: reward: 200.000, steps: 200
# Episode 71: reward: 200.000, steps: 200
# Episode 72: reward: 200.000, steps: 200
# Episode 73: reward: 200.000, steps: 200
# Episode 74: reward: 200.000, steps: 200
# Episode 75: reward: 200.000, steps: 200
# Episode 76: reward: 200.000, steps: 200
# Episode 77: reward: 200.000, steps: 200
# Episode 78: reward: 200.000, steps: 200
# Episode 79: reward: 200.000, steps: 200
# Episode 80: reward: 200.000, steps: 200
# Episode 81: reward: 200.000, steps: 200
# Episode 82: reward: 200.000, steps: 200
# Episode 83: reward: 200.000, steps: 200
# Episode 84: reward: 200.000, steps: 200
# Episode 85: reward: 200.000, steps: 200
# Episode 86: reward: 200.000, steps: 200
# Episode 87: reward: 200.000, steps: 200
# Episode 88: reward: 200.000, steps: 200
# Episode 89: reward: 200.000, steps: 200
# Episode 90: reward: 200.000, steps: 200
# Episode 91: reward: 200.000, steps: 200
# Episode 92: reward: 200.000, steps: 200
# Episode 93: reward: 200.000, steps: 200
# Episode 94: reward: 200.000, steps: 200
# Episode 95: reward: 200.000, steps: 200
# Episode 96: reward: 200.000, steps: 200
# Episode 97: reward: 200.000, steps: 200
# Episode 98: reward: 200.000, steps: 200
# Episode 99: reward: 200.000, steps: 200
# Episode 100: reward: 200.000, steps: 200
# 200.0

# %%
_ = dqn.test(env, nb_episodes=100, visualize=True)
# Out:
# Testing for 100 episodes ...
# Episode 1: reward: 200.000, steps: 200
# Episode 2: reward: 200.000, steps: 200
# Episode 3: reward: 200.000, steps: 200
# Episode 4: reward: 200.000, steps: 200
# Episode 5: reward: 200.000, steps: 200
# Episode 6: reward: 200.000, steps: 200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 _ = dqn.test(env, nb_episodes=100, visualize=True)
#
# File ~\anaconda3\envs\tf-tut\lib\site-packages\rl\core.py:352, in Agent.test(self, env, nb_episodes, action_repetition, callbacks, visualize, nb_max_episode_steps, nb_max_start_steps, start_step_policy, verbose)
#     350 if self.processor is not None:
#     351     observation, r, d, info = self.processor.process_step(observation, r, d, info)
# --> 352 callbacks.on_action_end(action)
#     353 reward += r
#     354 for key, value in info.items():
#
# File ~\anaconda3\envs\tf-tut\lib\site-packages\rl\callbacks.py:98, in CallbackList.on_action_end(self, action, logs)
#      96 for callback in self.callbacks:
#      97     if callable(getattr(callback, 'on_action_end', None)):
# ---> 98         callback.on_action_end(action, logs=logs)
#
# File ~\anaconda3\envs\tf-tut\lib\site-packages\rl\callbacks.py:360, in Visualizer.on_action_end(self, action, logs)
#     358 def on_action_end(self, action, logs):
#     359     """ Render environment at the end of each action """
# --> 360     self.env.render(mode='human')
#
# File ~\anaconda3\envs\tf-tut\lib\site-packages\gym\core.py:240, in Wrapper.render(self, mode, **kwargs)
#     239 def render(self, mode='human', **kwargs):
# --> 240     return self.env.render(mode, **kwargs)
#
# File ~\anaconda3\envs\tf-tut\lib\site-packages\gym\envs\classic_control\cartpole.py:213, in CartPoleEnv.render(self, mode)
#     210 self.carttrans.set_translation(cartx, carty)
#     211 self.poletrans.set_rotation(-x[2])
# --> 213 return self.viewer.render(return_rgb_array=mode == 'rgb_array')
#
# File ~\anaconda3\envs\tf-tut\lib\site-packages\gym\envs\classic_control\rendering.py:127, in Viewer.render(self, return_rgb_array)
#     125     arr = arr.reshape(buffer.height, buffer.width, 4)
#     126     arr = arr[::-1,:,0:3]
# --> 127 self.window.flip()
#     128 self.onetime_geoms = []
#     129 return arr if return_rgb_array else self.isopen
#
# File ~\anaconda3\envs\tf-tut\lib\site-packages\pyglet\window\win32\__init__.py:336, in Win32Window.flip(self)
#     334     if self._always_dwm or self._dwm_composition_enabled():
#     335         if self._interval:
# --> 336             _dwmapi.DwmFlush()
#     338 self.context.flip()
#
# KeyboardInterrupt:

# %% [markdown]
# # 4. Save model

# %%
dqn.save_weights('dqn_weights.h5f',overwrite=True)

# %%
del model
del dqn
del env

# Load model
env = gym.make('CartPole-v1')

# %% [markdown]
# ## Pickling a File

# %% [markdown]
# #### Save

# %%
# Step 1: Import Pickle
import pickle

# Step 2: Saving Variables
data = dqn
file_path = 'data.pickle'

# Open the file in binary mode
with open(file_path, 'wb') as file:
    # Serialize and write the variable to the file
    pickle.dump(data, file)


print("The variable 'data' has been saved successfully.")
# Out:
# INFO:tensorflow:Assets written to: ram://e0bdc4da-110a-45ea-9867-2b60c46cfe6e/assets
# INFO:tensorflow:Assets written to: ram://8560b711-c8ba-4141-b4a9-d0a39e11ffce/assets
# INFO:tensorflow:Assets written to: ram://153621bc-8fd9-4aae-822d-db3d490c73ef/assets
# INFO:tensorflow:Assets written to: ram://3f2c5cd2-f778-44ab-8e7a-e8ada0fce2eb/assets
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[28], line 11
#       8 # Open the file in binary mode
#       9 with open(file_path, 'wb') as file:
#      10     # Serialize and write the variable to the file
# ---> 11     pickle.dump(data, file)
#      14 print("The variable 'data' has been saved successfully.")
#
# File ~\anaconda3\envs\tf\lib\site-packages\keras\engine\training.py:363, in Model.__reduce__(self)
#     359 def __reduce__(self):
#     360     if self.built:
#     361         return (
#     362             pickle_utils.deserialize_model_from_bytecode,
# --> 363             pickle_utils.serialize_model_as_bytecode(self),
#     364         )
#     365     else:
#     366         # SavedModel (and hence serialize_model_as_bytecode) only support
#     367         # built models, but if the model is not built,
#    (...)
#     371         # the superclass hierarchy to get an implementation of __reduce__
#     372         # that can pickle this Model as a plain Python object.
#     373         return super().__reduce__()
#
# File ~\anaconda3\envs\tf\lib\site-packages\keras\saving\pickle_utils.py:63, in serialize_model_as_bytecode(model)
#      53 """Convert a Keras Model into a bytecode representation for pickling.
#      54
#      55 Args:
#    (...)
#      60         `deserialize_from_bytecode`.
#      61 """
#      62 temp_dir = f"ram://{uuid.uuid4()}"
# ---> 63 model.save(temp_dir)
#      64 b = io.BytesIO()
#      65 with tarfile.open(fileobj=b, mode="w") as archive:
#
# File ~\anaconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\envs\tf\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~\anaconda3\envs\tf\lib\copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File ~\anaconda3\envs\tf\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~\anaconda3\envs\tf\lib\copy.py:206, in _deepcopy_list(x, memo, deepcopy)
#     204 append = y.append
#     205 for a in x:
# --> 206     append(deepcopy(a, memo))
#     207 return y
#
# File ~\anaconda3\envs\tf\lib\copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~\anaconda3\envs\tf\lib\copy.py:297, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     295     for key, value in dictiter:
#     296         key = deepcopy(key, memo)
# --> 297         value = deepcopy(value, memo)
#     298         y[key] = value
#     299 else:
#
# File ~\anaconda3\envs\tf\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~\anaconda3\envs\tf\lib\copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File ~\anaconda3\envs\tf\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~\anaconda3\envs\tf\lib\copy.py:211, in _deepcopy_tuple(x, memo, deepcopy)
#     210 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 211     y = [deepcopy(a, memo) for a in x]
#     212     # We're not going to put the tuple in the memo, but it's still important we
#     213     # check for it, in case the tuple contains recursive mutable structures.
#     214     try:
#
# File ~\anaconda3\envs\tf\lib\copy.py:211, in <listcomp>(.0)
#     210 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 211     y = [deepcopy(a, memo) for a in x]
#     212     # We're not going to put the tuple in the memo, but it's still important we
#     213     # check for it, in case the tuple contains recursive mutable structures.
#     214     try:
#
# File ~\anaconda3\envs\tf\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~\anaconda3\envs\tf\lib\copy.py:211, in _deepcopy_tuple(x, memo, deepcopy)
#     210 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 211     y = [deepcopy(a, memo) for a in x]
#     212     # We're not going to put the tuple in the memo, but it's still important we
#     213     # check for it, in case the tuple contains recursive mutable structures.
#     214     try:
#
# File ~\anaconda3\envs\tf\lib\copy.py:211, in <listcomp>(.0)
#     210 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 211     y = [deepcopy(a, memo) for a in x]
#     212     # We're not going to put the tuple in the memo, but it's still important we
#     213     # check for it, in case the tuple contains recursive mutable structures.
#     214     try:
#
# File ~\anaconda3\envs\tf\lib\copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~\anaconda3\envs\tf\lib\copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File ~\anaconda3\envs\tf\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~\anaconda3\envs\tf\lib\copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File ~\anaconda3\envs\tf\lib\copy.py:153, in deepcopy(x, memo, _nil)
#     151 copier = getattr(x, "__deepcopy__", None)
#     152 if copier is not None:
# --> 153     y = copier(memo)
#     154 else:
#     155     reductor = dispatch_table.get(cls)
#
# FileNotFoundError: Unsuccessful TensorSliceReader constructor: Failed to find any matching files for ram://85592ad4-c883-4fc8-8486-4b1f1d6a2805/variables/variables
#  You may be trying to load on a different device from the computational device. Consider setting the `experimental_io_device` option in `tf.saved_model.LoadOptions` to the io_device such as '/job:localhost'.

# %% [markdown]
# #### Load

# %%
# Step 1: Import Pickle
import pickle

# Step 2: Saving Variables

# Step 3: Loading Variables
loaded_data = None
file_path = 'data.pickle'

# Open the file in binary mode
with open(file_path, 'rb') as file:
    # Deserialize and retrieve the variable from the file
    loaded_data = pickle.load(file)

print("The variable 'data' has been loaded successfully.")

print("Loaded Data:", loaded_data)

# %% [markdown]
# # dSPACE Interface

# %%
from win32com.client import Dispatch
from win32com.client import DispatchWithEvents
# from dspace.com import Enums
from pywintypes import com_error
import sys
# import exceptions
import numpy as np
import time
from time import sleep
# import matplotlib.pyplot as plt


Application =  Dispatch("ControlDeskNG.Application")
project_name = "Project_00X"
experiment_name = "Experiment_001"
platform_name = "Platform"


# Open project and experiment!
openProject = Application.ActiveProjectRoot.Projects[project_name].Open()
activeExperiment = openProject.Experiments[experiment_name].Activate()
myPlatform = Application.activeExperiment.Platforms[platform_name]

# Misc functions!
def scalify(array: np.ndarray):
    try:
        return array.item()
    except TypeError:
        return array
    except ValueError:
        return array

# %%
# (TUTORIAL) Access a variable!

start_loop_read = time.time()
for i in range(0, 1000):
    start = time.time()
    myVar = myPlatform.ActiveVariableDescription.Variables[str_Zd]
    stop = time.time()
#     print("Time required for reading a variable value: "+f'{(stop-start)*1000:.5f}'+" ms")
stop_loop_read = time.time()

start_loop_write = time.time()
for i in range(0, 1000):
    start = time.time()
    myVar.ValueConverted = 0.000005 + i
    stop = time.time()
#     print("Time required for changing a variable value: "+f'{(stop-start)*1000:.5f}'+" ms")
stop_loop_write = time.time()
myVar.ValueConverted = 0.00000

print("Time required for changing a variable value 1000 times: " +
      f'{(stop_loop_write-start_loop_write)*1000:.5f}' + " ms")
print("Time required for reading a variable value 1000 times: " +
      f'{(stop_loop_read-start_loop_read)*1000:.5f}' + " ms")

# The following !!DOES NOT WORK!!. You need to use the ".ValueConverted" every time!
# myVar_ez = myVar.ValueConverted
# myVar_ez = 10
# Out:
# Time required for changing a variable value 1000 times: 5839.15949 ms
# Time required for reading a variable value 1000 times: 6069.46754 ms

# %% [markdown]
# ## Parameter string names

# %%
# Control toggles
str_enable_Z_PID = 'Platform()://Model Root/get_plant_input/Z_1dctrl/Zctrl_enable/Value'
str_enable_grav = 'Platform()://Model Root/get_plant_input/Z_1dctrl/z_grav_ctrl_toggle/Value'
str_E_stop = 'Platform()://Model Root/get_plant_input/Z_1dctrl/EMERGENCY PAUSE/Value'

# Recording toggles & info
str_recording_safe_external = 'Platform()://Model Root/Monitoring/recording_safe_external/Value'
str_recording_discard_flag = 'Platform()://Model Root/Monitoring/recording_discard_flag/Value'
str_recording_reps_counter = 'Platform()://Model Root/Monitoring/reps_counter/Value'

# Input parameters
str_Zd = 'Platform()://Model Root/Input parameters/Z_desired_true/Value'
str_I_ratios = 'Platform()://Model Root/Input parameters/Ratio_perturb_desired/Value'
str_I_scale = 'Platform()://Model Root/Input parameters/Ratio_scale/Value'

# PID gains
str_gain_Pz = 'Platform()://Model Root/get_plant_input/Z_1dctrl/PID-Vertical/Pz/Gain'
str_gain_Iz = 'Platform()://Model Root/get_plant_input/Z_1dctrl/PID-Vertical/Iz/Gain'
str_gain_Dz = 'Platform()://Model Root/get_plant_input/Z_1dctrl/PID-Vertical/Dz/Value'


# Magnet specs
str_mag_height = 'Platform()://Model Root/Input parameters/Magnet Specs/Height/Value'
str_mag_height_m = 'Platform()://Model Root/Input parameters/Magnet Specs/height_m'
str_mag_diam = 'Platform()://Model Root/Input parameters/Magnet Specs/Diameter/Value'
str_mag_units = 'Platform()://Model Root/Input parameters/Magnet Specs/Units_mode/Value'

# Feedforward component 
str_feedforward_calibrate = 'Platform()://Model Root/get_plant_input/Z_1dctrl/FeedForward/lev_voltage_0.077m/Value'
    # ^ This is the voltage required to levitate the current magnet at 0.077m from the pole piece.

# Coil voltages (in V, after saturation)
str_coil0_voltage = 'Platform()://Model Root/get_plant_input/Z_1dctrl/Current2Vol1/Gain2/Out1[0]'
str_coil1_voltage = 'Platform()://Model Root/get_plant_input/Z_1dctrl/Current2Vol1/Gain2/Out1[1]'
str_coil2_voltage = 'Platform()://Model Root/get_plant_input/Z_1dctrl/Current2Vol1/Gain2/Out1[2]'
str_coil3_voltage = 'Platform()://Model Root/get_plant_input/Z_1dctrl/Current2Vol1/Gain2/Out1[3]'
str_coil4_voltage = 'Platform()://Model Root/get_plant_input/Z_1dctrl/Current2Vol1/Gain2/Out1[4]'
str_coil5_voltage = 'Platform()://Model Root/get_plant_input/Z_1dctrl/Current2Vol1/Gain2/Out1[5]'
str_coils_voltages = 'Platform()://Model Root/get_plant_input/Z_1dctrl/Current2Vol1/Gain2/Out1'

# Laser sensor readings
str_plant_head1_raw = 'Platform()://Model Root/plant/output signal/Head Z (V)/Out1'   # "Channel 1"
str_plant_head2_raw = 'Platform()://Model Root/plant/output signal/Head II (V)/Out1'  # "Channel 3"
str_plant_head3_raw = 'Platform()://Model Root/plant/output signal/Head III (V)/Out1' # "Channel 2"
str_plant_z_m = 'Platform()://Model Root/plant/Position Determination1/Z(m)'
str_plant_x_m = 'Platform()://Model Root/plant/Position Determination1/X(m)'
str_plant_y_m = 'Platform()://Model Root/plant/Position Determination1/Y(m)'

# Plant parameters
str_plant_z_restreading = 'Platform()://Model Root/plant/Position Determination1/Z position Calculation/empty platform reading/Value'
str_plant_x_cen = 'Platform()://Model Root/plant/Position Determination1/x_cen/Value'
str_plant_y_cen = 'Platform()://Model Root/plant/Position Determination1/y_cen/Value'

# Monitor parameters
str_monitor_off_head1_min = 'Platform()://Model Root/Monitoring/head1_off_min/Value'
str_monitor_off_head1_max = 'Platform()://Model Root/Monitoring/head1_off_max/Value'
str_monitor_off_head2_min = 'Platform()://Model Root/Monitoring/head2_off_min/Value'
str_monitor_off_head2_max = 'Platform()://Model Root/Monitoring/head2_off_max/Value'
str_monitor_off_head3_min = 'Platform()://Model Root/Monitoring/head3_off_min/Value'
str_monitor_off_head3_max = 'Platform()://Model Root/Monitoring/head3_off_max/Value'

str_monitor_empty_head1_min = 'Platform()://Model Root/Monitoring/head1_empty_min/Value'
str_monitor_empty_head1_max = 'Platform()://Model Root/Monitoring/head1_empty_max/Value'
str_monitor_empty_head2_min = 'Platform()://Model Root/Monitoring/head2_empty_min/Value'
str_monitor_empty_head2_max = 'Platform()://Model Root/Monitoring/head2_empty_max/Value'
str_monitor_empty_head3_min = 'Platform()://Model Root/Monitoring/head3_empty_min/Value'
str_monitor_empty_head3_max = 'Platform()://Model Root/Monitoring/head3_empty_max/Value'

str_monitor_rest_z_min = 'Platform()://Model Root/Monitoring/z_rest_min/Value'
str_monitor_rest_z_max = 'Platform()://Model Root/Monitoring/z_rest_max/Value'
str_monitor_z_iscalibrated = 'Platform()://Model Root/Monitoring/z-calibrated?/Value'
str_monitor_z_isresting = 'Platform()://Model Root/Monitoring/diagnostics_summary/resting'

str_monitor_time = 'Platform()://currentTime'  # Simulation time
str_monitor_in_workspace = 'Platform()://Model Root/Monitoring/diagnostics/in_workspace'
str_monitor_h1_empty = 'Platform()://Model Root/Monitoring/diagnostics/h1_empty'
str_monitor_h2_or_h3_empty = 'Platform()://Model Root/Monitoring/diagnostics/h2_or_h3_empty'
str_monitor_isstable = 'Platform()://Model Root/get_plant_input/choose_Z_d_temp/isstable/Out1'

str_diagnostic_quickreport = 'Platform()://Model Root/Monitoring/diagnostics_summary/quickreport'

# Convergence Indicators
str_converged_zd = 'Platform()://Model Root/get_plant_input/choose_Z_d_temp/z_converged/Out1'
str_close_zd = 'Platform()://Model Root/get_plant_input/detect_stability/z_goodenough'

# Variable-calling shortcut
dspace = myPlatform.ActiveVariableDescription.Variables

# %% [markdown]
# #### Define Calibration Functions

# %%
# Read min, mean, max of a sensor reading over some amount of real-time
def read_minmeanmax(string=str_plant_z_m, time_s = 10):
    start_loop_read = time.time()
    
    # Read initial values. Input must be a string that refers to a float, tuple, or array.
    i = 1
    reading_sum = np.asarray(dspace[string].ValueConverted)
    shape = reading_sum.shape
    reading_sum = reading_sum.ravel()
    reading_min = np.copy(reading_sum)
    reading_max = np.copy(reading_sum)
    reading_length = len(reading_sum)
    
    # Track mean, min, max
    while (time.time()-start_loop_read) < time_s:
        i += 1
        reading_looping = np.asarray(dspace[string].ValueConverted).ravel()
        reading_sum = reading_sum + reading_looping
        for j in range(0,reading_length):
            reading_min[j] = min(reading_min[j], reading_looping[j])
            reading_max[j] = max(reading_max[j], reading_looping[j])
        
    # Find mean
    reading_mean = reading_sum / i
    reading_min = scalify(reading_min.reshape(shape))
    reading_mean = scalify(reading_mean.reshape(shape))
    reading_max = scalify(reading_max.reshape(shape))
    
    return reading_min, reading_mean, reading_max

# Calibrate Z for platform WITH magnet on it
def calibrate_z(time_s = 10, platform_tilt_forgiveness_mm = 1):
    # Make sure gravity and Z-PID toggles are DISABLED before running!
    if (dspace[str_enable_Z_PID].ValueConverted==1 or dspace[str_enable_grav].ValueConverted==1) \
    and dspace[str_E_stop].ValueConverted==0:
        text = input("Z_PID is "+str(dspace[str_enable_Z_PID].ValueConverted)+\
                     ", grav is "+str(dspace[str_enable_grav].ValueConverted)+\
                     ", and E-stop is "+str(dspace[str_E_stop].ValueConverted)+\
                     ". Switch to the correct settings (0, 0, and 0) and begin? \n(yes/no)\n")
        if text.lower()=="yes":
            dspace[str_enable_Z_PID].ValueConverted = 0
            dspace[str_enable_grav].ValueConverted = 0
            dspace[str_E_stop].ValueConverted = 0
        else:
            raise ValueError("Disable Z_PID & gravity, or enable E-stop before running!")
            
    # Set "offset" to zero
    dspace[str_plant_z_restreading].ValueConverted = 0.0
    sleep(1)
    
    Zmin, Zmean, Zmax = read_minmeanmax(str_plant_z_m, time_s)
    dspace[str_plant_z_restreading].ValueConverted = -Zmean
    
    # Now, define min and max "rest" values for z.
    dspace[str_monitor_rest_z_min].ValueConverted = -platform_tilt_forgiveness_mm*0.001
    dspace[str_monitor_rest_z_max].ValueConverted =  platform_tilt_forgiveness_mm*0.001

    print("str_plant_z_restreading: "+str(-Zmean))
    print("str_monitor_rest_z_min: "+str(-platform_tilt_forgiveness_mm*0.001))
    print("str_monitor_rest_z_max: "+str( platform_tilt_forgiveness_mm*0.001))
    
    # And, indicate that calibration is done!
    dspace[str_monitor_z_iscalibrated].ValueConverted = 1
    
# Calibrate XY for levitating magnet
def calibrate_xy(time_s = 10):
    # Make sure gravity and Z-PID toggles are enabled before running!
    if dspace[str_enable_Z_PID].ValueConverted==0 or dspace[str_enable_grav].ValueConverted==0 \
    or dspace[str_E_stop].ValueConverted==1:
        text = input("Z_PID is "+str(dspace[str_enable_Z_PID].ValueConverted)+\
                     ", grav is "+str(dspace[str_enable_grav].ValueConverted)+\
                     ", and E-stop is "+str(dspace[str_E_stop].ValueConverted)+\
                     ". Switch to the correct settings (1, 1, and 0) and begin? \n(yes/no)\n")
        if text.lower()=="yes":
            dspace[str_enable_Z_PID].ValueConverted = 1
            dspace[str_enable_grav].ValueConverted = 1
            dspace[str_E_stop].ValueConverted = 0
        else:
            raise ValueError("Enable Z_PID & gravity, and disable E-stop before running!")
        
    # Make sure magnet is levitating before running!
    z_moveto(0.002)
    ratio_perturb_scaleto(0)
        
    # Set "offsets" to zero
    dspace[str_plant_x_cen].ValueConverted = 0.0
    dspace[str_plant_y_cen].ValueConverted = 0.0
    
    # Calibrate!
    Xmin, Xmean, Xmax = read_minmeanmax(str_plant_x_m, time_s)
    dspace[str_plant_x_cen].ValueConverted = Xmean
    Ymin, Ymean, Ymax = read_minmeanmax(str_plant_y_m, time_s)
    dspace[str_plant_y_cen].ValueConverted = Ymean
    sleep(1)
    z_moveto(0)
    
# Calibrate feedforward component for magnet
def calibrate_feedforward(dist_to_platform_m, time_s = 10, target_distance=0.077):
    input("Make sure gravity and z-PID toggles are ENABLED!")
    # Make sure magnet is levitating before running!
    
    if target_distance != 0.077:
        raise ValueError("Invalid target_distance-- only center=0.077m from "+\
                         "pole piece is allowed until a more sophisticated fit is implemented.")
    
    
    # Xiaodong's settings
    magnet_height_xiaodong = 0.010;
    dist_to_platform_xiaodong = 0.084    # Measured from bottom of pole-piece to top of platform for XD's magnet
    z_above_platform_xiaodong = 0.002    # z-setting for xiaodong, i.e. height of bottom of magnet above platform
    
    # My settings
    magnet_height = dspace[str_mag_height_m].ValueConverted
    dist_to_platform = dist_to_platform_m   # Measure before running!
    z_above_platform = (dist_to_platform - magnet_height/2) \
                     - (dist_to_platform_xiaodong - magnet_height_xiaodong/2 - z_above_platform_xiaodong)
    
    # Move to desired height
    print("Moving to "+str(z_above_platform))
    z_moveto(z_above_platform)
    ratio_perturb_scaleto(0)
    
    # Read values & return
    coilvolts_min, coilvolts_mean, coilvolt_max = read_minmeanmax(str_coils_voltages, time_s)
    levitation_voltage = np.mean(coilvolts_mean)
    print("Moving back to 0")
    z_moveto(0)
    
    # Calibrate!
    dspace[str_feedforward_calibrate].ValueConverted = levitation_voltage*0.99
    print("Calibration completed-- levitation voltage at "\
          +str(target_distance)+"m from pole-piece is "+str(levitation_voltage*0.99)+" V")
    
    
# Define "off" readings for head 1,2,3 signals
def define_off_h123(time_s = 30, tinytinyamount = 0.01):
    
    input("Make sure laser sensors are turned off!")

    [head1_min,deletthis,head1_max] = read_minmeanmax(str_plant_head1_raw, time_s)
    [head2_min,deletthis,head2_max] = read_minmeanmax(str_plant_head2_raw, time_s)
    [head3_min,deletthis,head3_max] = read_minmeanmax(str_plant_head3_raw, time_s)
    
    # Increase minmax range by a tiny, tiny amount.
    head1_extra = (head1_max - head1_min)*tinytinyamount
    head2_extra = (head2_max - head2_min)*tinytinyamount
    head3_extra = (head3_max - head3_min)*tinytinyamount

    print("Head1: "+str(head1_min)+" to "+str(head1_max))
    print("Head2: "+str(head2_min)+" to "+str(head2_max))
    print("Head3: "+str(head3_min)+" to "+str(head3_max))
    print("Adjusted by "+str(tinytinyamount*100)+"%:")
    print("Head1: "+str(head1_min - head1_extra)+" to "+str(head1_max + head1_extra))
    print("Head2: "+str(head2_min - head2_extra)+" to "+str(head2_max + head2_extra))
    print("Head3: "+str(head3_min - head3_extra)+" to "+str(head3_max + head3_extra))
    
    # Define boundaries in simulink/dspace.
    dspace[str_monitor_off_head1_min].ValueConverted = head1_min - head1_extra
    dspace[str_monitor_off_head1_max].ValueConverted = head1_max + head1_extra
    dspace[str_monitor_off_head2_min].ValueConverted = head2_min - head2_extra
    dspace[str_monitor_off_head2_max].ValueConverted = head2_max + head2_extra
    dspace[str_monitor_off_head3_min].ValueConverted = head3_min - head3_extra
    dspace[str_monitor_off_head3_max].ValueConverted = head3_max + head3_extra
    
    
# Define "empty" readings for head 1,2,3 signals
# Must be adjusted if the platform is ever moved!
def define_empty_h123(time_s = 10, tinytinyamount = 0.01):        
    input("Make sure the platform is empty!")

    [head1_min,deletthis,head1_max] = read_minmeanmax(str_plant_head1_raw, time_s)
    [head2_min,deletthis,head2_max] = read_minmeanmax(str_plant_head2_raw, time_s)
    [head3_min,deletthis,head3_max] = read_minmeanmax(str_plant_head3_raw, time_s)
    
    # Increase minmax range by a tiny, tiny amount.
#     tinytinyamount = 0.5 #fraction
    head1_extra = (head1_max - head1_min)*tinytinyamount
    head2_extra = (head2_max - head2_min)*tinytinyamount
    head3_extra = (head3_max - head3_min)*tinytinyamount

    print("Head1: "+str(head1_min)+" to "+str(head1_max))
    print("Head2: "+str(head2_min)+" to "+str(head2_max))
    print("Head3: "+str(head3_min)+" to "+str(head3_max))
    print("Adjusted by "+str(tinytinyamount*100)+"%:")
    print("Head1: "+str(head1_min - head1_extra)+" to "+str(head1_max + head1_extra))
    print("Head2: "+str(head2_min - head2_extra)+" to "+str(head2_max + head2_extra))
    print("Head3: "+str(head3_min - head3_extra)+" to "+str(head3_max + head3_extra))
    
    # Define boundaries in simulink/dspace.
    dspace[str_monitor_empty_head1_min].ValueConverted = head1_min - head1_extra
    dspace[str_monitor_empty_head1_max].ValueConverted = head1_max + head1_extra
    dspace[str_monitor_empty_head2_min].ValueConverted = head2_min - head2_extra
    dspace[str_monitor_empty_head2_max].ValueConverted = head2_max + head2_extra
    dspace[str_monitor_empty_head3_min].ValueConverted = head3_min - head3_extra
    dspace[str_monitor_empty_head3_max].ValueConverted = head3_max + head3_extra

    
# Define "rest" readings for x,y signals, even for magnets too 
# (Defining z-readings at rest is done in `calibrate_z`)
def define_rest_xy(time_s = 10):
    # LMAO NAH
    # This info is meaningless at "rest", since the magnet can just be placed anywhere on the platform!
    pass

# Set PID gains
def set_pid(P,I,D):
#     # Make sure Z-PID toggle is disabled before running!
#     if dspace[str_enable_Z_PID].ValueConverted==1:
#         raise ValueError(
#             "Disable Z_PID before running!")
    
    dspace[str_gain_Pz].ValueConverted = P
    dspace[str_gain_Iz].ValueConverted = I
    dspace[str_gain_Dz].ValueConverted = D
    
# Check if it's running in real time
def check_realtime(timer=10):
    start_time_true       = time.time()
    start_time_simulation = dspace[str_monitor_time].ValueConverted
    
    while time.time() < start_time_true+timer:
        sleep(0.0001)
    
    end_time_true = time.time()
    end_time_simulation = dspace[str_monitor_time].ValueConverted
    
    print("True timer error:       "+f'{(end_time_true - start_time_true - timer)*1000:.1f}'\
          +" ms out of "+ str(timer*1000)+" ms")
    print("Simulation timer error: "+f'{(end_time_simulation - start_time_simulation - timer)*1000:.1f}'\
          +" ms out of "+ str(timer*1000)+" ms")
    print("\nNote: The simulation timer error should remain relatively constant "\
          +"(i.e. ~several ms) regardless of how long this function's timer is."\
          +" If the error increases with the timer, then the system is NOT running in real time!")
    
# Set whether it's safe to gather training data!
def set_safe_to_record(safe):
    dspace[str_recording_safe_external].ValueConverted = safe

# Convert magnet specs to m
def convert_to_m(value):
    unit_mode = dspace[str_mag_units].ValueConverted   # can be 1, 2, 3, or 4
    # NOTE: Unit modes are:
    # 1 - m
    # 2 - cm
    # 3 - mm
    # 4 - in
    if unit_mode==1:
        units_to_m = 1
    elif unit_mode==2:
        units_to_m = 0.01
    elif unit_mode==3:
        units_to_m = 0.001
    elif unit_mode==4:
        units_to_m = 0.0254
    else:
        print("Invalid `str_mag_units` value of "+str(unit_mode)+". Must be 1, 2, 3, or 4.")
    value_m = value * units_to_m
    return value_m

# %% [markdown]
# #### Define Control-flow Functions

# %%
def diagnostics_parse(verbose=False):
    '''
    The `diagnostic_quickreport` condenses most important information into one
    large integer via one-hot encoding.
      00000001 : <empty>
      00000010 : Magnet resting status? (0, 1, 2, or 3; see "Detect resting...")
      00000100 : Is magnet's XY dangerously close to edge?
      00001000 : Is magnet converged?
      00010000 : Is magnet reasonably close to Zd?
      00100000 : Is magnet stable?
      01000000 : Is magnet detected by ALL sensors?
      10000000 : Is magnet detected by ANY sensor?
    '''
    global is_in_workspace
    global is_ready_to_run
    global is_stable
    global is_close
    global is_converged
    global is_xy_dangerzone
    global diagnostics_resting
    
    # Read `diagnostic_quickreport`
    quickreport = dspace[str_diagnostic_quickreport].ValueConverted
    if verbose:
        print(str(quickreport))
    
    # Parse it
    is_in_workspace         = get_digit(quickreport,8)
    is_ready_to_run         = get_digit(quickreport,7)
    is_stable               = get_digit(quickreport,6)
    is_close                = get_digit(quickreport,5)
    is_converged            = get_digit(quickreport,4)
    is_xy_dangerzone        = get_digit(quickreport,3)
    diagnostics_resting     = get_digit(quickreport,2)
    delet                   = get_digit(quickreport,1)
    
def get_digit(number, n):
    n = n-1
    return int(number // 10**n % 10)

# %% [markdown]
# % To modify

# %%
# def is_ready_to_run():
#     '''
#     Checks if magnet is in workspace-- particularly, if ALL sensors detect it!
#     '''
#     diagnostics_parse()
#     z_detected = not(dspace[str_monitor_h1_empty].ValueConverted)
#     xy_detected = not(dspace[str_monitor_h2_or_h3_empty].ValueConverted)
    
#     if z_detected and xy_detected:
#         return True
#     else:
#         return False
    
# def is_in_workspace():
#     '''
#     Checks if magnet is in workspace-- particularly, if ANY sensor detects it!
#     '''
#     z_detected = not(dspace[str_monitor_h1_empty].ValueConverted)
#     xy_detected = not(dspace[str_monitor_h2_or_h3_empty].ValueConverted)
    
#     if z_detected or xy_detected:
#         return True
#     else:
#         return False

def wait_converge(max_time = 15,check_diagnostics=False,mode='converge'):
    '''
    Waits for convergence.
    
    Parameters:
    -----------
        check_diagnostics=False
            If True, then it will check for various diagnostics (at a 
            slight responsiveness cost), and respond accordingly.
            Included diagnostics are:
                is_in_workspace       - Returns "abort-empty" if true
                is_ready_to_run       - 
                is_stable             - 
                is_close              - 
                is_converged          - 
                is_xy_dangerzone      - Returns "abort-toofar" if true
                diagnostics_resting   - 
        mode='converge' : str
            'converge' - Expects magnet to converge onto Zd before continuing.
            'close'    - Will continue as long as magnet is reasonably close to Zd.
    '''
        
    start_time = time.time()
    while time.time() < start_time+max_time:
        diagnostics_parse(verbose=False)
        # Choose condition based on `mode`.
        if mode.lower()=='converge':
            condition_is_met = is_converged
        elif mode.lower()=='close':
            condition_is_met = is_close
        else:
            raise ValueError("wait_converge() - Invalid 'mode'.")
        
        # Check if intervention is necessary
        if check_diagnostics==True:
            # Check if xy is too far / workspace is completely empty / magnet is unstable.
            if is_xy_dangerzone and is_in_workspace:
                print("wait_converge() Maximum radius reached! Returning to center.")
                return "abort-toofar"
            if not(is_in_workspace):
                print("wait_converge() WARNING: Magnet left workspace.")
                return "abort-empty"
            if not(is_stable):
                print("wait_converge() WARNING: Instability detected.")
                return "abort-instability"
                
        # Check if it's converged (or reasonably close, depending on `mode` parameter).
        # If not, then check if it just got stuck on platform.
        if condition_is_met:
            return "success"
        elif (time.time() > start_time+max_time/10) and diagnostics_resting == 1:
            print("wait_converge() WARNING: Magnet appears to be resting on platform.")
            return "success"
        else:
            diagnostics_parse()
        
#         # Check if it's dangerously far first!
#         if check_toofar==True:
#             x = dspace[str_plant_x_m].ValueConverted
#             y = dspace[str_plant_y_m].ValueConverted
#             r_m = np.sqrt(x**2 + y**2)
#             r_max_m = mag_radius_m * 0.9  # The 0.9 is arbitrary; adjust if needed.
#             if r_m > r_max_m:
#                 if dspace[str_monitor_in_workspace].ValueConverted==True:
#                     print("wait_converge() Maximum radius reached! Returning to center.")
#                     return "abort-toofar"
#                 else:
#                     print("wait_converge() WARNING: Max radius reached, but magnet left workspace!")
#                     return "abort-empty"
            
#         # Check if it's converged.
#         if dspace[str_converged_zd].ValueConverted == True:
#             return "success"
#         else:
#             # If magnet has not successfully converged yet...
#             if check_empty==True:
#                 if dspace[str_monitor_in_workspace].ValueConverted == False:
#                     print("wait_converge() WARNING: Magnet left workspace.")
#                     return "abort-empty"
#             if check_stability==True:
#                 if dspace[str_monitor_isstable].ValueConverted == False:
#                     print("wait_converge() WARNING: Instability detected.")
#                     return "abort-instability"
#             if check_empty==False and check_stability==False and check_toofar==False:
#                 sleep(0.001)
                
#             # Check for resting on platform
#             if time.time() > start_time+max_time/10:
#                 if dspace[str_monitor_z_isresting].ValueConverted == 1:
#                     return "success"
    
    # Timer has run out by this point. Check what to do next.
    diagnostics_parse()
    print("Timer out.")
    if is_close:
        print("wait_converge() Convergence timeout, but magnet is close enough to target to proceed.")
    else:
        # Check if it's detected in the workspace, but not by ALL sensors.
        if is_in_workspace and not(is_ready_to_run):
            # Jostle magnet until it's detected by ALL sensors!
            jostle_counter = 0
            while is_ready_to_run==False and jostle_counter < 10:
                dspace[str_I_scale].ValueConverted = max(dspace[str_I_scale].ValueConverted-0.05,0)
                wait_in_workspace()
                jostle_counter += 1
                diagnostics_parse()
        # Check if it's completely out of the workspace. Run recovery if so.
        elif not(is_in_workspace):
            recover_magnet()
        # By this point, something has gone horribly wrong. Human intervention is likely needed.
#         dspace[str_E_stop].ValueConverted = 1
#         raise ValueError("wait_converge() Convergence timeout error. E_Stop enabled")
        print("wait_converge() CRITICAL ERROR: Convergence timeout.")
        return "abort-timeout"
        
def wait_close(max_time = 5,check_diagnostics=False):
    '''
    Does `wait_converge()`, but with mode='close'.
    '''
    try:
        wait_converge(max_time,check_diagnostics=check_diagnostics,mode='close')
    except:
        try:
            wait_converge(max_time,check_diagnostics=True,mode='close')
        except:
            dspace[str_E_stop].ValueConverted = 1
            raise ValueError("wait_close() Closeness timeout error")

# %% [markdown]
# % Good

# %%
    
def z_set(z_d,max_time=5,mode="converge"):    
    dspace[str_Zd].ValueConverted = z_d
    if mode=="close":
        wait_close(max_time)
    elif mode=="converge":
        print("b")
        wait_converge(max_time)
    else:
        print("c")
        wait_converge(max_time)
    
def z_moveto(z_d,stepsize_m=0.00003,max_time=5):
    '''
    Moves the magnet from its current position to z_d relatively slowly, to keep 
    it converged onto the (changing) z_d_temp.
    '''    
    # Pop the thing off the ground first!
    init_height = 0.0005
    if (dspace[str_Zd].ValueConverted < init_height):
        dspace[str_Zd].ValueConverted = init_height
        wait_converge(max_time)
        sleep(1)
    
    # Now that it's levitating: start moving from z_d_orig to desired z_d!
    z_d_orig = dspace[str_Zd].ValueConverted
    z_d_temp = z_d_orig
    
    i = 1
    while True:
        z_d_temp += stepsize_m*np.sign(z_d - z_d_temp)
        z_set(z_d_temp,max_time,mode="close")
#         print(i)
        i += 1
        
        if np.abs(z_d_temp - z_d)<stepsize_m \
        or np.abs(dspace[str_plant_z_m].ValueConverted - z_d)<stepsize_m:
            z_set(z_d,max_time,mode="close")
            break

def recover_magnet(min_time = 0.1, max_time = 10, loop_counter = 0, max_jostle_attempts = 40):
    '''
    If magnet has left workspace, do:
    - enable emergency stop, letting the magnet fall
    - Once the magnet has been detected in the workspace for some time,
        set Zd to 2mm and restabilize
    - Do this several times in a row if it leaves workspace again
    '''
    # Back up current settings
    backup_recording_safe_external = dspace[str_recording_safe_external].ValueConverted
    backup_recording_discard_flag = dspace[str_recording_discard_flag].ValueConverted
    backup_E_stop = dspace[str_E_stop].ValueConverted
    backup_Zd = dspace[str_Zd].ValueConverted
    
    # Stop recording; discard run (if any)
    dspace[str_recording_safe_external].ValueConverted = 0
    dspace[str_recording_discard_flag].ValueConverted = 1
    
    # Hit emergency stop. Disable z-PID but NOT z-feedforward.
    # Lower I perturb scale (if any).
    dspace[str_I_scale].ValueConverted = max(dspace[str_I_scale].ValueConverted-0.005,0)
    print("recover_magnet() Dropping magnet. Waiting for detection in workspace...")
    dspace[str_enable_Z_PID].ValueConverted = 0
    dspace[str_enable_grav].ValueConverted = 1
    dspace[str_E_stop].ValueConverted = 1
    
    # Make sure magnet is detected by ALL sensors!
    jostle_counter = 0
    while is_ready_to_run==False and jostle_counter < max_jostle_attempts:
        dspace[str_I_scale].ValueConverted = max(dspace[str_I_scale].ValueConverted-0.05,0)
        wait_in_workspace(min_time,max_time)
        jostle_counter += 1
        diagnostics_parse()
    # All jostling attempts have failed by this point.
    while is_ready_to_run==False:
        dspace[str_I_scale].ValueConverted = 0
        input("recover_magnet() Max jostle count exceeded. Perturbation scale set to 0. Please manually recenter magnet.")
        diagnostics_parse()
    
    print("recover_magnet() Magnet recovered!")
        
#     print("recover_magnet() Now, reenabling PID and scaling down perturb. ratio...")
    # Once the magnet is safely in workspace again, reenable PID and bring it
    # to Zd=2mm while scaling down the perturbation scale.
    dspace[str_Zd].ValueConverted = 0.002
    dspace[str_enable_Z_PID].ValueConverted = 1
    dspace[str_enable_grav].ValueConverted = 1
    dspace[str_E_stop].ValueConverted = 0
        
    # Once it's hovering, centered, at 2.0mm: Restore original settings.
    dspace[str_recording_safe_external].ValueConverted = backup_recording_safe_external
    dspace[str_recording_discard_flag].ValueConverted = backup_recording_discard_flag
    z_moveto(backup_Zd)
    print("recover_magnet() Magnet has been recovered; ending function.")
    dspace[str_E_stop].ValueConverted = backup_E_stop
    print("Setting E-stop to: "+str(dspace[str_E_stop].ValueConverted))
        
    

    
def wait_in_workspace(min_time = 1.0, max_time = 10):
    '''
    Enables E-stop, and then "nudges" the magnet by enabling only feedforward control.
    Function ends when magnet is in workspace, even if not all 3 sensors detect it.
    '''
    # Back up current control settings
    toggle_Z_PID_backup  = dspace[str_enable_Z_PID].ValueConverted
    toggle_grav_backup   = dspace[str_enable_grav].ValueConverted
    toggle_E_stop_backup = dspace[str_E_stop].ValueConverted
    
    # Make sure E-stop is enabled; turn Z-PID off but Z-feedforward ON
    dspace[str_enable_Z_PID].ValueConverted = 0
    dspace[str_enable_grav].ValueConverted = 1
    dspace[str_E_stop].ValueConverted = 1
    
    workspace_reentry_time = time.time() # Reentry timer, counting up from 0
    start_time = time.time()
    while time.time() < start_time+max_time:
        if dspace[str_monitor_in_workspace].ValueConverted == 1:
            # If magnet reenters workspace: Disable e-stop, to let 
            # z-feedforward soften landing
            dspace[str_E_stop].ValueConverted = 0
            if time.time() - workspace_reentry_time > min_time:
                break
        else:
            # If magnet isn't in workspace, or if it leaves workspace again,
            # (re-)enable e-stop to let it fall, and reset timer.
            dspace[str_E_stop].ValueConverted = 1
            workspace_reentry_time = time.time()
            
    # Check if magnet failed to reenter workspace automatically
    if time.time() >= start_time+max_time:
        dspace[str_E_stop].ValueConverted = 1
        input("Magnet did not reenter workspace; please recenter magnet and confirm. Perturbation scale will be reset to 0.")
        dspace[str_I_scale].ValueConverted = 0
        
    # Magnet is on platform again; restore control toggles!
    dspace[str_enable_Z_PID].ValueConverted = toggle_Z_PID_backup
    dspace[str_enable_grav].ValueConverted = toggle_grav_backup
    dspace[str_E_stop].ValueConverted = toggle_E_stop_backup
            
            
    
# Generate random coil current perturbations, based on sinusoidal-like shape
def generate_coil_ratios(additional_perturb_max=0.05, fatness="random", offset="random",):
    '''
    Generates coil current ratios at maximum "scale" for the six-coil configuration
    (with each coil receiving a value from -1 to 1).
    
    For each coil C (where C = 1,2,3,4,5,6):
    
        I_perturb_C = | sin( offset + (C-1)*pi/3) |^beta
                      * sign( sin(offset + (C-1)*pi/3) )
                      + additional_perturb
    
    Params
    ------
    additional_perturb_max=0.05 : float
        Max/min value which additional_perturb can differ from 0.
    fatness="random" : float or str (positive only)
        Aka beta. Determines the shape of the "sinusoidal" orientation of coil perturbs.
        Setting to "random" will uniformly randomly select from 0.0001 to 10.
            Values closer to 0 are "very fat"; values beyond 10 are "very thin".
            Values close to 1 are sinusoidal.
    offset="random" : float or str (between 0 and 2pi)
        Determines the direction that the perturbations are pointed.
        
        
    Outputs
    -------
    coil_ratios : ndarray [6-vector]
        Coil ratios, ranging from -1 to 1, at maximum scale.
    '''
    def I_perturb_C(C,offset,beta,additional_perturb_max):
        additional_perturb = (np.random.rand()-0.5)*2 * additional_perturb_max
        return np.abs( np.sin( offset + (C-1)*np.pi/3) )**beta \
            * np.sign( np.sin( offset + (C-1)*np.pi/3) )\
            + additional_perturb, additional_perturb
    
    if fatness=="random":
        fatness = np.random.rand()*10
    if offset=="random":
        offset = np.random.rand()*2*np.pi
    
        
    coil_ratios = np.zeros(6)
    additional_perturbs = np.zeros(6)
    for C in [0,1,2,3,4,5]:
        coil_ratios[C], additional_perturbs[C] = I_perturb_C(C,offset,fatness,additional_perturb_max)
        
    return coil_ratios, additional_perturbs

# Slowly scale up the coil current ratios!
def ratio_perturb_scaleto(scale_target=0,speed_multiplier=1,check_empty=False):
    '''
    Scales the coil current perturbation scale from its initial value to the
    desired target, slowly.
    Pauses the scaling if the magnet (assumed levitating) goes too far from Z_d.

    Params:
    -------
    scale_target=0 : float
        Desired scale factor, ranging from 0 to 1.
    speed_multiplier=1 : float (positive)
        Higher values = faster speed.
        A value of 1000 jumps to the altered perturbation in one step.
    check_empty=False : bool
        If True, checks for whether workspace is empty (at a slight performance
        cost). If workspace is empty, will attempt "recovery" of the magnet.        
    '''
    
    # Start moving from scale_orig to scale_target!
    scale_orig = dspace[str_I_scale].ValueConverted
    scale_temp = scale_orig
    stepsize=0.001
    
    while True:
        scale_temp += stepsize*speed_multiplier*np.sign(scale_target - scale_temp)
        dspace[str_I_scale].ValueConverted = scale_temp
        sleep(0.001)
        
        # FEATURE ENGINEERING: Check if cancellation is due to instability or leaving workspace,
        #   so that bad data is scrapped accordingly later on.
        abort_report = wait_converge(max_time=5,check_diagnostics=True)
        if abort_report=='abort-instability':
            # Feature engineering behaviour: Ignore data where not converged 
            #   (already done in Simulink) and end run, but otherwise proceed 
            #   as normal.
            pass
        elif abort_report=='abort-empty':
            # Feature engineering behaviour: Scrap the entire run.
            dspace[str_recording_safe_external].ValueConverted = 0
            dspace[str_recording_discard_flag].ValueConverted = 1
            print("Attempting recovery...")
            recover_magnet()
            print("... Recovery successful!")
        elif abort_report == 'abort-toofar':
            # Excellent results! Do nothing.
            pass
        elif abort_report=='success':
            # Do nothing
            pass        
        
        # BEHAVIOUR: Abort or continue based on `abort-report`.
        if abort_report in ["abort-instability","abort-empty","abort-toofar"]:
            if np.sign(scale_target - scale_temp) > 0:
                x = dspace[str_plant_x_m].ValueConverted
                y = dspace[str_plant_y_m].ValueConverted
                r_m = np.sqrt(x**2 + y**2)
                print("ratio_perturb_scaleto() Cancelling rep at scale "\
                      +str(round(scale_temp,2))\
                      +"(X = " +str(round(x*1000,2))+ "mm),"\
                      +"(Y = " +str(round(y*1000,2))+ "mm),"\
                      +"(R = " +str(round(r_m*1000,2))+ "mm);"\
                      +" due to error '"+abort_report+"'.")
                break
                # End this function; i.e. cancel moving outwards.
            elif (scale_target - scale_temp)==0:
                # If fatal error occurred at exactly max scale, take a step back.
                print("Take a step back.")
                dspace[str_I_ratios].ValueConverted = I_ratio_prev
            else:
                pass
                # If it's already moving inwards, let it continue.
        
        # Completion
        if np.abs(scale_target - scale_temp)<stepsize*speed_multiplier:
            dspace[str_I_scale].ValueConverted = scale_target
            break
            
# Suddenly change the coil current ratios!
def ratio_perturb_set(I_ratio_target,step_size_fraction=1):
    '''
    Adds a coil current perturbation to the active perturbation ratio, then
    "centres" it (such that the total perturbation adds up to 0).

    Params:
    -------
    ratio_new : tuple
        Relative coil current ratio perturbation being added.
    step_size_fraction=1 : float (positive)
        Higher values = faster speed. Ranges from 0 to 1.
        A value of 1 jumps to the altered perturbation in one step.       
    '''
    
    # Start moving from old ratio to new ratio!
    
    # Calculate perturb. ratio increment
    I_ratio_prev = dspace[str_I_ratios].ValueConverted
    I_scale_prev = dspace[str_I_scale].ValueConverted
    I_ratio_target -= np.mean(I_ratio_target)
    additional_perturb = I_ratio_target - I_ratio_prev
    
    # Increment perturbation until it's fully applied!
    total_step_size = 0
    while total_step_size < 1:
        success = 0
        total_step_size = min(1,total_step_size+step_size_fraction)
        I_ratio = I_ratio_prev + total_step_size*additional_perturb
        dspace[str_I_ratios].ValueConverted = I_ratio
        
        # FEATURE ENGINEERING: Check if cancellation is due to instability or leaving workspace,
        #   so that bad data is scrapped accordingly later on.
        abort_report = wait_converge(max_time=5,check_diagnostics=True)
        if abort_report=='abort-instability':
            # Feature engineering behaviour: Ignore data where not converged 
            #   (already done in Simulink) and end run, but otherwise proceed 
            #   as normal.
            pass
        elif abort_report=='abort-empty':
            # Feature engineering behaviour: Scrap the entire run.
            dspace[str_recording_safe_external].ValueConverted = 0
            dspace[str_recording_discard_flag].ValueConverted = 1
            print("Attempting recovery...")
            recover_magnet()
            print("... Recovery successful!")
        elif abort_report == 'abort-toofar':
            # Excellent results! Do nothing.
            pass
        elif abort_report=='success':
            # Do nothing
            pass
        elif abort_report=="abort-timeout":
            # Feature engineering behaviour: Record for later reference. Don't use this as training data tho.
            pass
        
        # BEHAVIOUR: Abort or continue based on `abort-report`.
        if abort_report in ["abort-instability","abort-toofar"]:
            print("Too close to edge! Take a step back.")
            dspace[str_I_ratios].ValueConverted = I_ratio_prev
            dspace[str_I_scale].ValueConverted = I_scale_prev
            break
        elif abort_report in ["abort-empty","abort-timeout"]:
            print("CRITICAL ERROR! Attempting to hard reset.")
            dspace[str_I_ratios].ValueConverted = (0,0,0,0,0,0)
            recover_magnet()
            dspace[str_I_scale].ValueConverted = I_scale_prev
            break
            
        # Successful?
        success = 1
            

    # Was it successful?
    if success==1:
        print("Success!")
        return 0
    else:
        print("ratio_perturb_add() - Ended ratio perturbing at total_step_size: "+str(total_step_size)+" out of 1.0")
        return 1

# %% [markdown]
# ### Run Utilities & Initial Calibration

# %%
# Reconnect after rebuilding
dspace = myPlatform.ActiveVariableDescription.Variables

# %%
set_pid(400,500,6000)

# %%
calibrate_z(10, platform_tilt_forgiveness_mm=0.1)

# %%
mag_diameter_m = convert_to_m(dspace[str_mag_diam].ValueConverted)
mag_radius_m = mag_diameter_m / 2
calibrate_xy(time_s=10)

# %% [markdown]
# ### Test Run

# %%
z_moveto(z_d=0.00,stepsize_m=0.00003)

# %%
recover_magnet(min_time=0.1)

# %% [markdown]
# ## Data-gathering loop:
# #### Choose perturbation completely randomly -> apply it -> wait until converge -> repeat

# %%
# Initial settings
max_time_minutes = 3
Z_d = 0.002

# %%
I_ratio_target

# %%
min(I_ratio_target)

# %%
# Get magnet specs
mag_diameter_m = convert_to_m(dspace[str_mag_diam].ValueConverted)
mag_radius_m = mag_diameter_m / 2

# Make sure gravity and Z-PID toggles are enabled before running!
dspace[str_I_scale].ValueConverted = 1
dspace[str_I_ratios].ValueConverted = (0,0,0,0,0,0)
if dspace[str_enable_Z_PID].ValueConverted==0 or dspace[str_enable_grav].ValueConverted==0 \
or dspace[str_E_stop].ValueConverted==1:
    text = input("Z_PID is "+str(dspace[str_enable_Z_PID].ValueConverted)+\
                 ", grav is "+str(dspace[str_enable_grav].ValueConverted)+\
                 ", and E-stop is "+str(dspace[str_E_stop].ValueConverted)+\
                 ". Switch to the correct settings (1, 1, and 0) and begin? \n(yes/no)\n")
    if text.lower()=="yes":
        dspace[str_enable_Z_PID].ValueConverted = 1
        dspace[str_enable_grav].ValueConverted = 1
        dspace[str_E_stop].ValueConverted = 0
    else:
        raise ValueError("Enable Z_PID & gravity, and disable E-stop before running!")
    
# Move to Zd
z_moveto(Z_d,max_time=5)

# Begin looping
start_timer = time.time()
n_consecutive_fails = 0
while True:
    # Increment rep
    dspace[str_recording_reps_counter].ValueConverted += 1
    
    # Generate desired perturb. ratio. Do not allow any of the coils to generate "negative" currents, though.
    I_ratio_prev = dspace[str_I_ratios].ValueConverted
    while True:
        [ignore,additional_perturb] = generate_coil_ratios(additional_perturb_max=0.8)
        I_ratio_target = I_ratio_prev + additional_perturb
        I_ratio_target -= np.mean(I_ratio_target)
        if min(I_ratio_target)>-1:
            break
    
    # Reset the per-rep diagnostics
    dspace[str_recording_discard_flag].ValueConverted = 0
    dspace[str_recording_safe_external].ValueConverted = 1
    set_safe_to_record(1)

    # Begin rep!
    print("Beginning rep "+str(np.round(dspace[str_recording_reps_counter].ValueConverted))+\
          "... (desired ratio: "+str(np.round(1+I_ratio_target,3))+")")
    # Apply new perturb. ratio
    did_it_fail = ratio_perturb_set(I_ratio_target,step_size_fraction=0.25)
    
    if did_it_fail:
        n_consecutive_fails = n_consecutive_fails + did_it_fail
        if n_consecutive_fails>3:
            print("... Seems to be stuck here. Reset to centre!")
            dspace[str_I_ratios].ValueConverted = (0,0,0,0,0,0)
            wait_converge(check_diagnostics=True)
            dspace[str_I_scale].ValueConverted = 1
            n_consecutive_fails = 0
    else:
        n_consecutive_fails = 0
    sleep(0.5)
    print("")

    
    
    # Cooldown period
    if time.time() - start_timer > max_time_minutes * 60:
        print("Cooldown ...")
        ratio_perturb_scaleto(scale_target=0,speed_multiplier=50)
        # Pause recording and let it cool down for a bit.
        dspace[str_recording_safe_external].ValueConverted = 0
        z_moveto(0.00)
        dspace[str_E_stop].ValueConverted = 1
        for minutes in range(0,max_time_minutes):
            for seconds in range(0,60):
                sleep(1)
        dspace[str_E_stop].ValueConverted = 0
        z_moveto(Z_d,max_time=5)
        dspace[str_recording_safe_external].ValueConverted = 1
        print("... Cooldown complete!\n")
        dspace[str_I_ratios].ValueConverted = (0,0,0,0,0,0)
        dspace[str_I_scale].ValueConverted = 1
        start_timer = time.time()
    else:
        pass
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[240], line 76
#      74 for minutes in range(0,max_time_minutes):
#      75     for seconds in range(0,60):
# ---> 76         sleep(1)
#      77 dspace[str_E_stop].ValueConverted = 0
#      78 z_moveto(Z_d,max_time=5)
#
# KeyboardInterrupt:

# %%
dspace[str_I_scale].ValueConverted

# %%
# ?wait_converge

# %%
dspace[str_I_ratios].ValueConverted

# %%
dspace[str_I_scale].ValueConverted

# %% [markdown]
# ## Data-gathering loop (OLD):
# #### Choose perturbation -> gently scale to that perturbation

# %%
# Initial settings
max_time_minutes = 3

# %%
# Get magnet specs
mag_diameter_m = convert_to_m(dspace[str_mag_diam].ValueConverted)
mag_radius_m = mag_diameter_m / 2

# Make sure gravity and Z-PID toggles are enabled before running!
if dspace[str_enable_Z_PID].ValueConverted==0 or dspace[str_enable_grav].ValueConverted==0 \
or dspace[str_E_stop].ValueConverted==1:
    text = input("Z_PID is "+str(dspace[str_enable_Z_PID].ValueConverted)+\
                 ", grav is "+str(dspace[str_enable_grav].ValueConverted)+\
                 ", and E-stop is "+str(dspace[str_E_stop].ValueConverted)+\
                 ". Switch to the correct settings (1, 1, and 0) and begin? \n(yes/no)\n")
    if text.lower()=="yes":
        dspace[str_enable_Z_PID].ValueConverted = 1
        dspace[str_enable_grav].ValueConverted = 1
        dspace[str_E_stop].ValueConverted = 0
    else:
        raise ValueError("Enable Z_PID & gravity, and disable E-stop before running!")
    
# Heights
Z_d = 0.002
z_moveto(Z_d,max_time=5)

# Center the magnet if it hasn't already been done
if dspace[str_I_scale].ValueConverted != 0:
    ratio_perturb_scaleto(scale_target=0)

start_timer = time.time()

while True:
    # Increment rep
    dspace[str_recording_reps_counter].ValueConverted += 1
    
    # Generate desired perturb. ratio
    ratio_perturb_desired, additional_perturbs = generate_coil_ratios(additional_perturb_max=0.05, \
                                                                      fatness="random", offset="random",)
    dspace[str_I_ratios].ValueConverted = ratio_perturb_desired
    
    # Reset the per-rep diagnostics
    dspace[str_recording_discard_flag].ValueConverted = 0
    dspace[str_recording_safe_external].ValueConverted = 1

    # Begin rep!
    print("Beginning rep "+str(np.round(dspace[str_recording_reps_counter].ValueConverted))+\
          "... (desired ratio: "+str(np.round(ratio_perturb_desired,2))+")")
    # Bring ratio scale up and down
    set_safe_to_record(1)
    ratio_perturb_scaleto(scale_target=1,speed_multiplier=1.3)
    print("... ")
    ratio_perturb_scaleto(scale_target=0,speed_multiplier=1.3)
    print("... rep "+str(dspace[str_recording_reps_counter].ValueConverted)+" complete!\n")

    # Cooldown period
    if time.time() - start_timer > max_time_minutes * 60:
        print("Cooldown ...")
        # Pause recording and let it cool down for a bit.
        dspace[str_recording_safe_external].ValueConverted = 0
        z_moveto(0.00)
        dspace[str_E_stop].ValueConverted = 1
        for minutes in range(0,max_time_minutes):
            for seconds in range(0,60):
                sleep(1)
        dspace[str_E_stop].ValueConverted = 0
        z_moveto(Z_d,max_time=5)
        dspace[str_recording_safe_external].ValueConverted = 1
        print("... Cooldown complete!\n")
        start_timer = time.time()
    else:
        pass

# %% [markdown]
# Data to gather:
#
# times = seconds(ttable.('Time'));
# z_pos = ttable.('Labels_z_pos');
# x_pos = ttable.('Labels_x_pos');
# y_pos = ttable.('Labels_y_pos');
# z0 = ttable.('Labels_z0');
# offset = ttable.('Labels_offset_rad');
# fatness = ttable.('Labels_fatness');
# scale = ttable.('Labels_scale');
# status_report = ttable.('Labels_status_report');
# I_ratio_perturb0 = ttable.('Labels_Ratio_perturbation_0_');  % Input "perturbations" to the coils, scale included.
# I_ratio_perturb1 = ttable.('Labels_Ratio_perturbation_1_');  % Input "perturbations" to the coils, scale included.
# I_ratio_perturb2 = ttable.('Labels_Ratio_perturbation_2_');  % Input "perturbations" to the coils, scale included.
# I_ratio_perturb3 = ttable.('Labels_Ratio_perturbation_3_');  % Input "perturbations" to the coils, scale included.
# I_ratio_perturb4 = ttable.('Labels_Ratio_perturbation_4_');  % Input "perturbations" to the coils, scale included.
# I_ratio_perturb5 = ttable.('Labels_Ratio_perturbation_5_');  % Input "perturbations" to the coils, scale included.
# I_final0 = ttable.('Labels_I_req_currents_yesgrav_0_');  % Input "currents" to the coils, scale included.
# I_final1 = ttable.('Labels_I_req_currents_yesgrav_1_');  % Input "currents" to the coils, scale included.
# I_final2 = ttable.('Labels_I_req_currents_yesgrav_2_');  % Input "currents" to the coils, scale included.
# I_final3 = ttable.('Labels_I_req_currents_yesgrav_3_');  % Input "currents" to the coils, scale included.
# I_final4 = ttable.('Labels_I_req_currents_yesgrav_4_');  % Input "currents" to the coils, scale included.
# I_final5 = ttable.('Labels_I_req_currents_yesgrav_5_');  % Input "currents" to the coils, scale included.
# (!) Create additional variables for discarding reps that are not successful (e.g. could not stabilize, left workspace, etc)

# %% [markdown]
# ### (Need to do whenever platform is adjusted!)

# %%
# Reconnect after rebuilding
dspace = myPlatform.ActiveVariableDescription.Variables

# %%
define_empty_h123(30, tinytinyamount=0.05)

# %%
# Re-measure distance to platform (i.e. bottom of pole-piece to top of platform)
# when platform is adjusted!
dist_to_platform_m = 0.083
calibrate_feedforward(dist_to_platform_m=dist_to_platform_m)

# %%
# (Not actually necessary)
define_off_h123(10, tinytinyamount=0.05)

# %% [markdown]
# ## Considerations:
# * Keep it running in REAL TIME if possible! (**Simulation time** and **actual clock time** are not the same!)

# %%
check_realtime(10)
